# %%
import sys
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
italy = gpd.read_file('italy-with-regions/reg2011_g.shp')
#new_regions = pd.read_csv('/content/drive/My Drive/Colab Notebooks/TensorFlow 2.0/maps/reg2011_g.csv')
#covid = pd.read_csv('/content/drive/My Drive/Colab Notebooks/TensorFlow 2.0/maps/Covid.csv')

# %% [markdown]
# https://medium.com/@ardito.bryan/creating-a-covid-19-map-of-italy-using-python-1f3182c1fd88

# %%
italy.plot(figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %%
vaccini = pd.read_csv('../covid19-opendata-vaccini/dati/vaccini-summary-latest.csv')
vaccini = vaccini.set_index('area')
sum_ = vaccini.loc[['PAT', 'PAB']].sum().to_frame().transpose()
sum_ = sum_.rename(index={0: 'TRE'})

vaccini.drop(['PAT', 'PAB'],inplace=True)
vaccini = vaccini.append(sum_)
vaccini = vaccini.sort_index()

# %%
italy.sort_values(by = 'NOME_REG', inplace = True)
italy.reset_index(drop=True,       inplace = True)
italy
# Out:
#     COD_REG                                           NOME_REG    SHAPE_Leng  \
# 0        13                                            ABRUZZO  6.145137e+05
# 1        17                                         BASILICATA  6.142192e+05
# 2        18                                           CALABRIA  8.381944e+05
# 3        15                                           CAMPANIA  8.923791e+05
# 4         8                                     EMILIA-ROMAGNA  1.164723e+06
# 5         6                              FRIULI VENEZIA GIULIA  6.674897e+05
# 6        12                                              LAZIO  1.055355e+06
# 7         7                                            LIGURIA  8.342245e+05
# 8         3                                          LOMBARDIA  1.411265e+06
# 9        11                                             MARCHE  6.292090e+05
# 10       14                                             MOLISE  4.338747e+05
# 11        1                                           PIEMONTE  1.236869e+06
# 12       16                                             PUGLIA  1.176243e+06
# 13       20                                           SARDEGNA  1.460657e+06
# 14       19                                            SICILIA  1.339974e+06
# 15        9                                            TOSCANA  1.316658e+06
# 16        4                       TRENTINO-ALTO ADIGE/SUDTIROL  8.005341e+05
# 17       10                                             UMBRIA  6.203152e+05
# 18        2  VALLE D'AOSTA/VALLÉE D'AOSTE\r\nVALLE D'AOSTA/...  3.111651e+05
# 19        5                                             VENETO  1.057856e+06
#
#       SHAPE_Area                                           geometry
# 0   1.082910e+10  POLYGON ((901880.250 4760558.000, 901910.750 4...
# 1   1.007326e+10  MULTIPOLYGON (((1074503.688 4446135.938, 10744...
# 2   1.521668e+10  MULTIPOLYGON (((1084888.411 4414364.607, 10848...
# 3   1.366399e+10  MULTIPOLYGON (((925294.173 4528798.912, 925329...
# 4   2.245147e+10  MULTIPOLYGON (((760714.748 4937319.399, 760723...
# 5   7.864294e+09  MULTIPOLYGON (((852211.994 5080672.916, 852270...
# 6   1.722762e+10  MULTIPOLYGON (((802704.568 4594643.932, 802540...
# 7   5.415465e+09  MULTIPOLYGON (((400403.625 4851436.938, 400257...
# 8   2.386270e+10  MULTIPOLYGON (((595736.187 5163715.001, 596126...
# 9   9.401178e+09  MULTIPOLYGON (((863162.283 4840139.829, 863195...
# 10  4.461149e+09  POLYGON ((984090.000 4670910.250, 985154.250 4...
# 11  2.539410e+10  POLYGON ((457832.312 5145701.000, 458745.249 5...
# 12  1.953708e+10  MULTIPOLYGON (((1141891.750 4588535.750, 11418...
# 13  2.409417e+10  MULTIPOLYGON (((432678.313 4492760.313, 432811...
# 14  2.582478e+10  MULTIPOLYGON (((803299.052 4188096.575, 803275...
# 15  2.298443e+10  MULTIPOLYGON (((593650.250 4867988.000, 593553...
# 16  1.360802e+10  POLYGON ((743386.080 5219948.900, 743472.190 5...
# 17  8.464008e+09  MULTIPOLYGON (((771407.451 4833282.073, 771402...
# 18  3.259041e+09  POLYGON ((390734.999 5091965.001, 390830.999 5...
# 19  1.840550e+10  POLYGON ((768209.001 5175597.001, 768220.251 5...

# %%
italy.index = vaccini.index
italy
# Out:
#      COD_REG                                           NOME_REG    SHAPE_Leng  \
# ABR       13                                            ABRUZZO  6.145137e+05
# BAS       17                                         BASILICATA  6.142192e+05
# CAL       18                                           CALABRIA  8.381944e+05
# CAM       15                                           CAMPANIA  8.923791e+05
# EMR        8                                     EMILIA-ROMAGNA  1.164723e+06
# FVG        6                              FRIULI VENEZIA GIULIA  6.674897e+05
# LAZ       12                                              LAZIO  1.055355e+06
# LIG        7                                            LIGURIA  8.342245e+05
# LOM        3                                          LOMBARDIA  1.411265e+06
# MAR       11                                             MARCHE  6.292090e+05
# MOL       14                                             MOLISE  4.338747e+05
# PIE        1                                           PIEMONTE  1.236869e+06
# PUG       16                                             PUGLIA  1.176243e+06
# SAR       20                                           SARDEGNA  1.460657e+06
# SIC       19                                            SICILIA  1.339974e+06
# TOS        9                                            TOSCANA  1.316658e+06
# TRE        4                       TRENTINO-ALTO ADIGE/SUDTIROL  8.005341e+05
# UMB       10                                             UMBRIA  6.203152e+05
# VDA        2  VALLE D'AOSTA/VALLÉE D'AOSTE\r\nVALLE D'AOSTA/...  3.111651e+05
# VEN        5                                             VENETO  1.057856e+06
#
#        SHAPE_Area                                           geometry
# ABR  1.082910e+10  POLYGON ((901880.250 4760558.000, 901910.750 4...
# BAS  1.007326e+10  MULTIPOLYGON (((1074503.688 4446135.938, 10744...
# CAL  1.521668e+10  MULTIPOLYGON (((1084888.411 4414364.607, 10848...
# CAM  1.366399e+10  MULTIPOLYGON (((925294.173 4528798.912, 925329...
# EMR  2.245147e+10  MULTIPOLYGON (((760714.748 4937319.399, 760723...
# FVG  7.864294e+09  MULTIPOLYGON (((852211.994 5080672.916, 852270...
# LAZ  1.722762e+10  MULTIPOLYGON (((802704.568 4594643.932, 802540...
# LIG  5.415465e+09  MULTIPOLYGON (((400403.625 4851436.938, 400257...
# LOM  2.386270e+10  MULTIPOLYGON (((595736.187 5163715.001, 596126...
# MAR  9.401178e+09  MULTIPOLYGON (((863162.283 4840139.829, 863195...
# MOL  4.461149e+09  POLYGON ((984090.000 4670910.250, 985154.250 4...
# PIE  2.539410e+10  POLYGON ((457832.312 5145701.000, 458745.249 5...
# PUG  1.953708e+10  MULTIPOLYGON (((1141891.750 4588535.750, 11418...
# SAR  2.409417e+10  MULTIPOLYGON (((432678.313 4492760.313, 432811...
# SIC  2.582478e+10  MULTIPOLYGON (((803299.052 4188096.575, 803275...
# TOS  2.298443e+10  MULTIPOLYGON (((593650.250 4867988.000, 593553...
# TRE  1.360802e+10  POLYGON ((743386.080 5219948.900, 743472.190 5...
# UMB  8.464008e+09  MULTIPOLYGON (((771407.451 4833282.073, 771402...
# VDA  3.259041e+09  POLYGON ((390734.999 5091965.001, 390830.999 5...
# VEN  1.840550e+10  POLYGON ((768209.001 5175597.001, 768220.251 5...

# %%
italy = italy.merge(vaccini,left_index=True, right_index=True, how='right')
italy['percentuale_somministrazione'] = italy['dosi_somministrate'] / italy['dosi_consegnate'] * 100
italy
# Out:
#      COD_REG                                           NOME_REG    SHAPE_Leng  \
# ABR       13                                            ABRUZZO  6.145137e+05
# BAS       17                                         BASILICATA  6.142192e+05
# CAL       18                                           CALABRIA  8.381944e+05
# CAM       15                                           CAMPANIA  8.923791e+05
# EMR        8                                     EMILIA-ROMAGNA  1.164723e+06
# FVG        6                              FRIULI VENEZIA GIULIA  6.674897e+05
# LAZ       12                                              LAZIO  1.055355e+06
# LIG        7                                            LIGURIA  8.342245e+05
# LOM        3                                          LOMBARDIA  1.411265e+06
# MAR       11                                             MARCHE  6.292090e+05
# MOL       14                                             MOLISE  4.338747e+05
# PIE        1                                           PIEMONTE  1.236869e+06
# PUG       16                                             PUGLIA  1.176243e+06
# SAR       20                                           SARDEGNA  1.460657e+06
# SIC       19                                            SICILIA  1.339974e+06
# TOS        9                                            TOSCANA  1.316658e+06
# TRE        4                       TRENTINO-ALTO ADIGE/SUDTIROL  8.005341e+05
# UMB       10                                             UMBRIA  6.203152e+05
# VDA        2  VALLE D'AOSTA/VALLÉE D'AOSTE\r\nVALLE D'AOSTA/...  3.111651e+05
# VEN        5                                             VENETO  1.057856e+06
#
#        SHAPE_Area                                           geometry  \
# ABR  1.082910e+10  POLYGON ((901880.250 4760558.000, 901910.750 4...
# BAS  1.007326e+10  MULTIPOLYGON (((1074503.688 4446135.938, 10744...
# CAL  1.521668e+10  MULTIPOLYGON (((1084888.411 4414364.607, 10848...
# CAM  1.366399e+10  MULTIPOLYGON (((925294.173 4528798.912, 925329...
# EMR  2.245147e+10  MULTIPOLYGON (((760714.748 4937319.399, 760723...
# FVG  7.864294e+09  MULTIPOLYGON (((852211.994 5080672.916, 852270...
# LAZ  1.722762e+10  MULTIPOLYGON (((802704.568 4594643.932, 802540...
# LIG  5.415465e+09  MULTIPOLYGON (((400403.625 4851436.938, 400257...
# LOM  2.386270e+10  MULTIPOLYGON (((595736.187 5163715.001, 596126...
# MAR  9.401178e+09  MULTIPOLYGON (((863162.283 4840139.829, 863195...
# MOL  4.461149e+09  POLYGON ((984090.000 4670910.250, 985154.250 4...
# PIE  2.539410e+10  POLYGON ((457832.312 5145701.000, 458745.249 5...
# PUG  1.953708e+10  MULTIPOLYGON (((1141891.750 4588535.750, 11418...
# SAR  2.409417e+10  MULTIPOLYGON (((432678.313 4492760.313, 432811...
# SIC  2.582478e+10  MULTIPOLYGON (((803299.052 4188096.575, 803275...
# TOS  2.298443e+10  MULTIPOLYGON (((593650.250 4867988.000, 593553...
# TRE  1.360802e+10  POLYGON ((743386.080 5219948.900, 743472.190 5...
# UMB  8.464008e+09  MULTIPOLYGON (((771407.451 4833282.073, 771402...
# VDA  3.259041e+09  POLYGON ((390734.999 5091965.001, 390830.999 5...
# VEN  1.840550e+10  POLYGON ((768209.001 5175597.001, 768220.251 5...
#
#     dosi_somministrate dosi_consegnate percentuale_somministrazione  \
# ABR              24609           38680                       63.622
# BAS              15244           20775                      73.3767
# CAL              32484           62680                      51.8251
# CAM             147734          173695                      85.0537
# EMR             162643          220925                      73.6191
# FVG              43253           60715                      71.2394
# LAZ             170632          230170                       74.133
# LIG              47258           77540                      60.9466
# LOM             264918          379530                      69.8016
# MAR              37427           45380                      82.4747
# MOL               8784           13505                      65.0426
# PIE             166572          200980                      82.8799
# PUG              94315          120235                      78.4422
# SAR              32550           53220                      61.1612
# SIC             137156          201115                      68.1978
# TOS             107498          133840                      80.3183
# TRE              43155           57575                      74.9544
# UMB              19381           24875                      77.9136
# VDA               4674            6460                      72.3529
# VEN             153075          197240                      77.6085
#
#      ultimo_aggiornamento
# ABR            2021-01-29
# BAS            2021-01-29
# CAL            2021-01-29
# CAM            2021-01-29
# EMR            2021-01-29
# FVG            2021-01-29
# LAZ            2021-01-29
# LIG            2021-01-29
# LOM            2021-01-29
# MAR            2021-01-29
# MOL            2021-01-29
# PIE            2021-01-29
# PUG            2021-01-29
# SAR            2021-01-29
# SIC            2021-01-29
# TOS            2021-01-29
# TRE  2021-01-292021-01-29
# UMB            2021-01-29
# VDA            2021-01-29
# VEN            2021-01-29

# %%
import matplotlib.colors as mcolors
import matplotlib.cm as cm

fig, ax = plt.subplots(1, figsize=(15, 15))

col = 'percentuale_somministrazione'

ax.set_title('Percentuale somministrazioni per regione', 
             fontdict={'fontsize':'25', 'fontweight':'3'}, 
             color='Orange', 
             fontfamily='monospace')


normalize = mcolors.Normalize(vmin=italy['percentuale_somministrazione'].min(), vmax=italy['percentuale_somministrazione'].max())
#colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap="Blues")
scalarmappaple.set_array(italy['percentuale_somministrazione'])

italy.plot(ax=ax,
           column=col,
           cmap="Blues"
#           cmap=colormap,
#           label='ciao',
#          legend=True,
#           categorical=False
#           alpha = 1
          )

plt.axis('off')
plt.colorbar(scalarmappaple)

# %%
vaccini
# Out:
#     dosi_somministrate dosi_consegnate percentuale_somministrazione  \
# ABR              24609           38680                         63.6
# BAS              15244           20775                         73.4
# CAL              32484           62680                         51.8
# CAM             147734          173695                         85.1
# EMR             162643          220925                         73.6
# FVG              43253           60715                         71.2
# LAZ             170632          230170                         74.1
# LIG              47258           77540                         60.9
# LOM             264918          379530                         69.8
# MAR              37427           45380                         82.5
# MOL               8784           13505                           65
# PIE             166572          200980                         82.9
# PUG              94315          120235                         78.4
# SAR              32550           53220                         61.2
# SIC             137156          201115                         68.2
# TOS             107498          133840                         80.3
# TRE              43155           57575                        148.6
# UMB              19381           24875                         77.9
# VDA               4674            6460                         72.4
# VEN             153075          197240                         77.6
#
#      ultimo_aggiornamento
# ABR            2021-01-29
# BAS            2021-01-29
# CAL            2021-01-29
# CAM            2021-01-29
# EMR            2021-01-29
# FVG            2021-01-29
# LAZ            2021-01-29
# LIG            2021-01-29
# LOM            2021-01-29
# MAR            2021-01-29
# MOL            2021-01-29
# PIE            2021-01-29
# PUG            2021-01-29
# SAR            2021-01-29
# SIC            2021-01-29
# TOS            2021-01-29
# TRE  2021-01-292021-01-29
# UMB            2021-01-29
# VDA            2021-01-29
# VEN            2021-01-29

# %%
emr = gpd.read_file('regions-with-provinces/emilia-romagna/emilia-romagna.shp')
emr.plot(figsize=(10, 10))
emr['popolazione'] = 0
emr.loc[0, 'popolazione'] = 453317
emr.loc[1, 'popolazione'] = 531891
emr.loc[2, 'popolazione'] = 284329
emr.loc[3, 'popolazione'] = 398322
emr.loc[4, 'popolazione'] = 705545
emr.loc[5, 'popolazione'] = 1020096
emr.loc[6, 'popolazione'] = 343742
emr.loc[7, 'popolazione'] = 388863
emr.loc[8, 'popolazione'] = 339796
emr
# Out:
#    COD_REG  COD_PRO            NOME_PRO     SHAPE_Leng    SHAPE_Area  \
# 0        8       34               PARMA  321806.521064  3.445759e+09
# 1        8       35  REGGIO NELL'EMILIA  262764.090160  2.290916e+09
# 2        8       33            PIACENZA  329995.998007  2.585975e+09
# 3        8       40       FORLI'-CESENA  257464.827880  2.377070e+09
# 4        8       36              MODENA  333870.099638  2.688018e+09
# 5        8       37             BOLOGNA  399729.647717  3.702298e+09
# 6        8       38             FERRARA  337073.363835  2.635969e+09
# 7        8       39             RAVENNA  297587.521805  1.860219e+09
# 8        8       99              RIMINI  254032.045367  8.652411e+08
#
#                                             geometry  popolazione
# 0  POLYGON ((593614.999 4986968.501, 594057.001 4...       453317
# 1  POLYGON ((636403.553 4983188.219, 636419.000 4...       531891
# 2  MULTIPOLYGON (((572263.999 4994625.501, 572348...       284329
# 3  POLYGON ((745273.001 4909886.001, 745548.719 4...       398322
# 4  MULTIPOLYGON (((664869.849 4980703.577, 665370...       705545
# 5  POLYGON ((681224.562 4963512.501, 680353.626 4...      1020096
# 6  POLYGON ((737846.001 4984968.502, 737961.001 4...       343742
# 7  MULTIPOLYGON (((760714.748 4937319.399, 760723...       388863
# 8  POLYGON ((779658.901 4891752.842, 780275.015 4...       339796

# %%
province = pd.read_csv('../../contagio/COVID-19/dati-province/dpc-covid19-ita-province.csv')
province.data = pd.to_datetime(province.data)
province.data = province.data.dt.strftime('%d/%m/%Y')

# %%
province_grouped = province.groupby(province.denominazione_provincia)
ferrara = province_grouped.get_group('Ferrara')
bologna = province_grouped.get_group('Bologna')
rimini = province_grouped.get_group('Rimini')
ravenna = province_grouped.get_group('Ravenna')
modena = province_grouped.get_group('Modena')
forlì_cesena = province_grouped.get_group('Forlì-Cesena')
piacenza = province_grouped.get_group('Piacenza')
reggio_emilia = province_grouped.get_group("Reggio nell'Emilia")
parma = province_grouped.get_group('Parma')
parma
# Out:
#              data stato  codice_regione denominazione_regione  \
# 21     24/02/2020   ITA               8        Emilia-Romagna
# 149    25/02/2020   ITA               8        Emilia-Romagna
# 277    26/02/2020   ITA               8        Emilia-Romagna
# 405    27/02/2020   ITA               8        Emilia-Romagna
# 533    28/02/2020   ITA               8        Emilia-Romagna
# ...           ...   ...             ...                   ...
# 47378  24/01/2021   ITA               8        Emilia-Romagna
# 47527  25/01/2021   ITA               8        Emilia-Romagna
# 47676  26/01/2021   ITA               8        Emilia-Romagna
# 47825  27/01/2021   ITA               8        Emilia-Romagna
# 47974  28/01/2021   ITA               8        Emilia-Romagna
#
#        codice_provincia denominazione_provincia sigla_provincia        lat  \
# 21                   34                   Parma              PR  44.801074
# 149                  34                   Parma              PR  44.801074
# 277                  34                   Parma              PR  44.801074
# 405                  34                   Parma              PR  44.801074
# 533                  34                   Parma              PR  44.801074
# ...                 ...                     ...             ...        ...
# 47378                34                   Parma              PR  44.801074
# 47527                34                   Parma              PR  44.801074
# 47676                34                   Parma              PR  44.801074
# 47825                34                   Parma              PR  44.801074
# 47974                34                   Parma              PR  44.801074
#
#            long  totale_casi note codice_nuts_1 codice_nuts_2 codice_nuts_3
# 21     10.32835            0  NaN           NaN           NaN           NaN
# 149    10.32835            4  NaN           NaN           NaN           NaN
# 277    10.32835            8  NaN           NaN           NaN           NaN
# 405    10.32835           10  NaN           NaN           NaN           NaN
# 533    10.32835           27  NaN           NaN           NaN           NaN
# ...         ...          ...  ...           ...           ...           ...
# 47378  10.32835        14489  NaN           ITH          ITH5         ITH52
# 47527  10.32835        14538  NaN           ITH          ITH5         ITH52
# 47676  10.32835        14586  NaN           ITH          ITH5         ITH52
# 47825  10.32835        14633  NaN           ITH          ITH5         ITH52
# 47974  10.32835        14690  NaN           ITH          ITH5         ITH52
#
# [340 rows x 14 columns]

# %%
from datetime import date, timedelta
yesterday = (date.today() - timedelta(days=1)).strftime('%d/%m/%Y')
today = date.today().strftime('%d/%m/%Y')

province_grouped = province.groupby(province.data)
province_oggi    = province_grouped.get_group(yesterday)
province_oggi

province_gruppo  = province_oggi.groupby(province.denominazione_regione)
province_emr1     = province_gruppo.get_group('Emilia-Romagna')
province_emr1
# Out:
#              data stato  codice_regione denominazione_regione  \
# 47973  28/01/2021   ITA               8        Emilia-Romagna
# 47974  28/01/2021   ITA               8        Emilia-Romagna
# 47975  28/01/2021   ITA               8        Emilia-Romagna
# 47976  28/01/2021   ITA               8        Emilia-Romagna
# 47977  28/01/2021   ITA               8        Emilia-Romagna
# 47978  28/01/2021   ITA               8        Emilia-Romagna
# 47979  28/01/2021   ITA               8        Emilia-Romagna
# 47980  28/01/2021   ITA               8        Emilia-Romagna
# 47981  28/01/2021   ITA               8        Emilia-Romagna
# 47982  28/01/2021   ITA               8        Emilia-Romagna
# 47983  28/01/2021   ITA               8        Emilia-Romagna
#
#        codice_provincia               denominazione_provincia sigla_provincia  \
# 47973                33                              Piacenza              PC
# 47974                34                                 Parma              PR
# 47975                35                    Reggio nell'Emilia              RE
# 47976                36                                Modena              MO
# 47977                37                               Bologna              BO
# 47978                38                               Ferrara              FE
# 47979                39                               Ravenna              RA
# 47980                40                          Forlì-Cesena              FC
# 47981                99                                Rimini              RN
# 47982               884    Fuori Regione / Provincia Autonoma             NaN
# 47983               984  In fase di definizione/aggiornamento             NaN
#
#              lat       long  totale_casi note codice_nuts_1 codice_nuts_2  \
# 47973  45.051935   9.692633        17543  NaN           ITH          ITH5
# 47974  44.801074  10.328350        14690  NaN           ITH          ITH5
# 47975  44.697353  10.630080        28798  NaN           ITH          ITH5
# 47976  44.646000  10.926155        37211  NaN           ITH          ITH5
# 47977  44.494367  11.341721        47991  NaN           ITH          ITH5
# 47978  44.835991  11.618689        12350  NaN           ITH          ITH5
# 47979  44.417225  12.199139        16260  NaN           ITH          ITH5
# 47980  44.222686  12.040686        17128  NaN           ITH          ITH5
# 47981  44.060901  12.565630        19336  NaN           ITH          ITH5
# 47982        NaN        NaN         2417  NaN           ITH          ITH5
# 47983        NaN        NaN         1030  NaN           ITH          ITH5
#
#       codice_nuts_3
# 47973         ITH51
# 47974         ITH52
# 47975         ITH53
# 47976         ITH54
# 47977         ITH55
# 47978         ITH56
# 47979         ITH57
# 47980         ITH58
# 47981         ITH59
# 47982           NaN
# 47983           NaN

# %%
province_emr = province_emr1.set_index('denominazione_provincia')
province_emr = province_emr.sort_index()
emr.sort_values(by = 'NOME_PRO', inplace = True)
emr.reset_index(drop=True,       inplace = True)

province_emr.drop(['Fuori Regione / Provincia Autonoma', 'In fase di definizione/aggiornamento'],inplace=True)

emr.index = province_emr.index
emr_def = emr.merge(province_emr,left_index=True, right_index=True, how='right')
emr_def['per_100000'] = emr_def['totale_casi'] / emr['popolazione'] * 1000
emr_def
# Out:
#                          COD_REG  COD_PRO            NOME_PRO     SHAPE_Leng  \
# denominazione_provincia
# Bologna                        8       37             BOLOGNA  399729.647717
# Ferrara                        8       38             FERRARA  337073.363835
# Forlì-Cesena                   8       40       FORLI'-CESENA  257464.827880
# Modena                         8       36              MODENA  333870.099638
# Parma                          8       34               PARMA  321806.521064
# Piacenza                       8       33            PIACENZA  329995.998007
# Ravenna                        8       39             RAVENNA  297587.521805
# Reggio nell'Emilia             8       35  REGGIO NELL'EMILIA  262764.090160
# Rimini                         8       99              RIMINI  254032.045367
#
#                            SHAPE_Area  \
# denominazione_provincia
# Bologna                  3.702298e+09
# Ferrara                  2.635969e+09
# Forlì-Cesena             2.377070e+09
# Modena                   2.688018e+09
# Parma                    3.445759e+09
# Piacenza                 2.585975e+09
# Ravenna                  1.860219e+09
# Reggio nell'Emilia       2.290916e+09
# Rimini                   8.652411e+08
#
#                                                                   geometry  \
# denominazione_provincia
# Bologna                  POLYGON ((681224.562 4963512.501, 680353.626 4...
# Ferrara                  POLYGON ((737846.001 4984968.502, 737961.001 4...
# Forlì-Cesena             POLYGON ((745273.001 4909886.001, 745548.719 4...
# Modena                   MULTIPOLYGON (((664869.849 4980703.577, 665370...
# Parma                    POLYGON ((593614.999 4986968.501, 594057.001 4...
# Piacenza                 MULTIPOLYGON (((572263.999 4994625.501, 572348...
# Ravenna                  MULTIPOLYGON (((760714.748 4937319.399, 760723...
# Reggio nell'Emilia       POLYGON ((636403.553 4983188.219, 636419.000 4...
# Rimini                   POLYGON ((779658.901 4891752.842, 780275.015 4...
#
#                          popolazione        data stato  codice_regione  ...  \
# denominazione_provincia                                                 ...
# Bologna                      1020096  28/01/2021   ITA               8  ...
# Ferrara                       343742  28/01/2021   ITA               8  ...
# Forlì-Cesena                  398322  28/01/2021   ITA               8  ...
# Modena                        705545  28/01/2021   ITA               8  ...
# Parma                         453317  28/01/2021   ITA               8  ...
# Piacenza                      284329  28/01/2021   ITA               8  ...
# Ravenna                       388863  28/01/2021   ITA               8  ...
# Reggio nell'Emilia            531891  28/01/2021   ITA               8  ...
# Rimini                        339796  28/01/2021   ITA               8  ...
#
#                         codice_provincia  sigla_provincia        lat  \
# denominazione_provincia
# Bologna                               37               BO  44.494367
# Ferrara                               38               FE  44.835991
# Forlì-Cesena                          40               FC  44.222686
# Modena                                36               MO  44.646000
# Parma                                 34               PR  44.801074
# Piacenza                              33               PC  45.051935
# Ravenna                               39               RA  44.417225
# Reggio nell'Emilia                    35               RE  44.697353
# Rimini                                99               RN  44.060901
#
#                               long  totale_casi  note codice_nuts_1  \
# denominazione_provincia
# Bologna                  11.341721        47991   NaN           ITH
# Ferrara                  11.618689        12350   NaN           ITH
# Forlì-Cesena             12.040686        17128   NaN           ITH
# Modena                   10.926155        37211   NaN           ITH
# Parma                    10.328350        14690   NaN           ITH
# Piacenza                  9.692633        17543   NaN           ITH
# Ravenna                  12.199139        16260   NaN           ITH
# Reggio nell'Emilia       10.630080        28798   NaN           ITH
# Rimini                   12.565630        19336   NaN           ITH
#
#                         codice_nuts_2 codice_nuts_3 per_100000
# denominazione_provincia
# Bologna                          ITH5         ITH55  47.045572
# Ferrara                          ITH5         ITH56  35.928109
# Forlì-Cesena                     ITH5         ITH58  43.000387
# Modena                           ITH5         ITH54  52.740789
# Parma                            ITH5         ITH52  32.405579
# Piacenza                         ITH5         ITH51  61.699651
# Ravenna                          ITH5         ITH57  41.814212
# Reggio nell'Emilia               ITH5         ITH53  54.142672
# Rimini                           ITH5         ITH59  56.904731
#
# [9 rows x 21 columns]

# %%
fig, ax = plt.subplots(1, figsize=(15, 15))

col = 'per_100000'

ax.set_title('Casi per provincia per 1000 abitanti', 
             fontdict={'fontsize':'25', 'fontweight':'3'}, 
             color='Orange', 
             fontfamily='monospace')


normalize = mcolors.Normalize(vmin=emr_def['per_100000'].min(), vmax=emr_def['per_100000'].max())
#colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap="Blues")
scalarmappaple.set_array(emr_def['per_100000'])

emr_def.plot(ax=ax,
             column=col,
             cmap="Blues"
#            cmap=colormap,
#            label='ciao',
#            legend=True,
#            categorical=False
#            alpha = 1
           )

plt.axis('off')
cbar = plt.colorbar(scalarmappaple, shrink=0.3)
cbar.ax.tick_params(labelsize=11)

ax.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=ax.transAxes,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')
#print(italy)
plt.savefig('emr.png', dpi = 300)
