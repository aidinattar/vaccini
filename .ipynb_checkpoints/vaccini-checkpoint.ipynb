# %%
import numpy as np
import matplotlib.pyplot as plt  # To visualize
import pandas as pd  # To read data
import matplotlib.dates as mdates

plt.plot()
# Out:
# []

# %%
anag       = pd.read_csv('../covid19-opendata-vaccini/dati/anagrafica-vaccini-summary-latest.csv')  # load data set
somm1      = pd.read_csv('../covid19-opendata-vaccini/dati/somministrazioni-vaccini-latest.csv')
cons       = pd.read_csv('../covid19-opendata-vaccini/dati/consegne-vaccini-latest.csv')
somm2      = pd.read_csv('../covid19-opendata-vaccini/dati/somministrazioni-vaccini-summary-latest.csv')
punti_somm = pd.read_csv('../covid19-opendata-vaccini/dati/punti-somministrazione-latest.csv')
vaccini    = pd.read_csv('../covid19-opendata-vaccini/dati/vaccini-summary-latest.csv')

total = vaccini['dosi_consegnate'].sum()
cons_g = cons.groupby(cons.area)
cons_g.get_group('EMR')

somm2
# Out:
#     data_somministrazione area  totale  sesso_maschile  sesso_femminile  \
# 0              2020-12-27  PAT     102              39               63
# 1              2020-12-27  PIE     912             368              544
# 2              2020-12-27  CAM     720             422              298
# 3              2020-12-27  PAB     143              65               78
# 4              2020-12-27  SAR      65              34               31
# ..                    ...  ...     ...             ...              ...
# 546            2021-01-23  LAZ    6791            2658             4133
# 547            2021-01-23  UMB     277             100              177
# 548            2021-01-23  FVG     392             145              247
# 549            2021-01-23  PUG    2791            1175             1616
# 550            2021-01-23  PIE    4107            1284             2823
#
#      categoria_operatori_sanitari_sociosanitari  \
# 0                                            77
# ...

# %%
somm2_grouped = somm2.groupby(somm2.area)
somm2_ita     = somm2_grouped.get_group('ITA')
somm2_emr     = somm2_grouped.get_group('EMR')
somm2_ven     = somm2_grouped.get_group('VEN')
somm2_abr     = somm2_grouped.get_group('ABR')
somm2_bas     = somm2_grouped.get_group('BAS')
somm2_cal     = somm2_grouped.get_group('CAL')
somm2_cam     = somm2_grouped.get_group('CAM')
somm2_fvg     = somm2_grouped.get_group('FVG')
somm2_laz     = somm2_grouped.get_group('LAZ')
somm2_lom     = somm2_grouped.get_group('LOM')
somm2_lig     = somm2_grouped.get_group('LIG')
somm2_mar     = somm2_grouped.get_group('MAR')
somm2_mol     = somm2_grouped.get_group('MOL')
somm2_pab     = somm2_grouped.get_group('PAB')
somm2_pat     = somm2_grouped.get_group('PAT')
somm2_pie     = somm2_grouped.get_group('PIE')
somm2_pug     = somm2_grouped.get_group('PUG')
somm2_sar     = somm2_grouped.get_group('SAR')
somm2_sic     = somm2_grouped.get_group('SIC')
somm2_tos     = somm2_grouped.get_group('TOS')
somm2_umb     = somm2_grouped.get_group('UMB')
somm2_vda     = somm2_grouped.get_group('VDA')

somm2_ita['percentuale_dosi'] = somm2_ita['totale'] / total   * 100
somm2_ita['per_1000']       = somm2_ita['totale'] / 60360
somm2_emr['per_1000']       = somm2_emr['totale'] / 4459
somm2_ven['per_1000']       = somm2_ven['totale'] / 4906
somm2_abr['per_1000']       = somm2_abr['totale'] / 1312
somm2_bas['per_1000']       = somm2_bas['totale'] / 562.869
somm2_cal['per_1000']       = somm2_cal['totale'] / 1947
somm2_cam['per_1000']       = somm2_cam['totale'] / 5802
somm2_fvg['per_1000']       = somm2_fvg['totale'] / 1215
somm2_laz['per_1000']       = somm2_laz['totale'] / 5879
somm2_lom['per_1000']       = somm2_lom['totale'] / 10060
somm2_lig['per_1000']       = somm2_lig['totale'] / 1551
somm2_mar['per_1000']       = somm2_mar['totale'] / 1525
somm2_mol['per_1000']       = somm2_mol['totale'] / 305.617
somm2_pab['per_1000']       = somm2_pab['totale'] / 520.891
somm2_pat['per_1000']       = somm2_pat['totale'] / 739.139
somm2_pie['per_1000']       = somm2_pie['totale'] / 4356
somm2_pug['per_1000']       = somm2_pug['totale'] / 4029
somm2_sar['per_1000']       = somm2_sar['totale'] / 1640
somm2_sic['per_1000']       = somm2_sic['totale'] / 5000
somm2_tos['per_1000']       = somm2_tos['totale'] / 3730
somm2_umb['per_1000']       = somm2_umb['totale'] / 882.015
somm2_vda['per_1000']       = somm2_vda['totale'] / 125.666

somm2_ita['prima_1000']       = somm2_ita['prima_dose'] / 60360
somm2_emr['prima_1000']       = somm2_emr['prima_dose'] / 4459
somm2_ven['prima_1000']       = somm2_ven['prima_dose'] / 4906
somm2_abr['prima_1000']       = somm2_abr['prima_dose'] / 1312
somm2_bas['prima_1000']       = somm2_bas['prima_dose'] / 562.869
somm2_cal['prima_1000']       = somm2_cal['prima_dose'] / 1947
somm2_cam['prima_1000']       = somm2_cam['prima_dose'] / 5802
somm2_fvg['prima_1000']       = somm2_fvg['prima_dose'] / 1215
somm2_laz['prima_1000']       = somm2_laz['prima_dose'] / 5879
somm2_lom['prima_1000']       = somm2_lom['prima_dose'] / 10060
somm2_lig['prima_1000']       = somm2_lig['prima_dose'] / 1551
somm2_mar['prima_1000']       = somm2_mar['prima_dose'] / 1525
somm2_mol['prima_1000']       = somm2_mol['prima_dose'] / 305.617
somm2_pab['prima_1000']       = somm2_pab['prima_dose'] / 520.891
somm2_pat['prima_1000']       = somm2_pat['prima_dose'] / 739.139
somm2_pie['prima_1000']       = somm2_pie['prima_dose'] / 4356
somm2_pug['prima_1000']       = somm2_pug['prima_dose'] / 4029
somm2_sar['prima_1000']       = somm2_sar['prima_dose'] / 1640
somm2_sic['prima_1000']       = somm2_sic['prima_dose'] / 5000
somm2_tos['prima_1000']       = somm2_tos['prima_dose'] / 3730
somm2_umb['prima_1000']       = somm2_umb['prima_dose'] / 882.015
somm2_vda['prima_1000']       = somm2_vda['prima_dose'] / 125.666

somm2_ita['seconda_1000']       = somm2_ita['seconda_dose'] / 60360
somm2_emr['seconda_1000']       = somm2_emr['seconda_dose'] / 4459
somm2_ven['seconda_1000']       = somm2_ven['seconda_dose'] / 4906
somm2_abr['seconda_1000']       = somm2_abr['seconda_dose'] / 1312
somm2_bas['seconda_1000']       = somm2_bas['seconda_dose'] / 562.869
somm2_cal['seconda_1000']       = somm2_cal['seconda_dose'] / 1947
somm2_cam['seconda_1000']       = somm2_cam['seconda_dose'] / 5802
somm2_fvg['seconda_1000']       = somm2_fvg['seconda_dose'] / 1215
somm2_laz['seconda_1000']       = somm2_laz['seconda_dose'] / 5879
somm2_lom['seconda_1000']       = somm2_lom['seconda_dose'] / 10060
somm2_lig['seconda_1000']       = somm2_lig['seconda_dose'] / 1551
somm2_mar['seconda_1000']       = somm2_mar['seconda_dose'] / 1525
somm2_mol['seconda_1000']       = somm2_mol['seconda_dose'] / 305.617
somm2_pab['seconda_1000']       = somm2_pab['seconda_dose'] / 520.891
somm2_pat['seconda_1000']       = somm2_pat['seconda_dose'] / 739.139
somm2_pie['seconda_1000']       = somm2_pie['seconda_dose'] / 4356
somm2_pug['seconda_1000']       = somm2_pug['seconda_dose'] / 4029
somm2_sar['seconda_1000']       = somm2_sar['seconda_dose'] / 1640
somm2_sic['seconda_1000']       = somm2_sic['seconda_dose'] / 5000
somm2_tos['seconda_1000']       = somm2_tos['seconda_dose'] / 3730
somm2_umb['seconda_1000']       = somm2_umb['seconda_dose'] / 882.015
somm2_vda['seconda_1000']       = somm2_vda['seconda_dose'] / 125.666


somm2_pab
# Out:
# <ipython-input-95-a38863438952>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   somm2_ita['percentuale_dosi'] = somm2_ita['totale'] / total   * 100
# <ipython-input-95-a38863438952>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   somm2_ita['per_1000']       = somm2_ita['totale'] / 60360
# <ipython-input-95-a38863438952>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
plt.rcParams["figure.dpi"] = 140

# %matplotlib widget

somm2_emr.plot(x ='data_somministrazione', y='totale', kind = 'bar', title = "emilia romagna")
somm2_ita.plot(x ='data_somministrazione', y='totale', kind = 'bar', title = "italia")
somm2_ven.plot(x ='data_somministrazione', y='totale', kind = 'bar', title = "veneto")
somm2_lom.plot(x ='data_somministrazione', y='totale', kind = 'bar', title = "lombardia")
somm2_pat.plot(x ='data_somministrazione', y='totale', kind = 'bar', title = "trento")

somm2_ita.plot(x ='data_somministrazione', y='percentuale_dosi', kind = 'bar', title = "italia percentuale")

somm2_ita.plot(x ='data_somministrazione', y='per_1000', kind = 'bar', title = "italia per 1000")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:title={'center':'italia per 1000'}, xlabel='data_somministrazione'>

# %%
# %matplotlib inline
fig, axes = plt.subplots(nrows=3, ncols=7,sharex=False, sharey=True, gridspec_kw={'hspace': 1.25, 'wspace': 0}, dpi = 200)

#fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})

somm2_abr.plot(ax=axes[0,0], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "ABR")
somm2_bas.plot(ax=axes[0,1], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "BAS")
somm2_cal.plot(ax=axes[0,2], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "CAL")
somm2_cam.plot(ax=axes[0,3], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "CAM")
somm2_emr.plot(ax=axes[0,4], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "EMR")
somm2_fvg.plot(ax=axes[0,5], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "FVG")
somm2_laz.plot(ax=axes[0,6], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "LAZ")
somm2_lig.plot(ax=axes[1,0], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "LIG")
somm2_lom.plot(ax=axes[1,1], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "LOM")
somm2_mar.plot(ax=axes[1,2], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "MAR")
somm2_mol.plot(ax=axes[1,3], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "MOL")
somm2_pab.plot(ax=axes[1,4], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "PAB")
somm2_pat.plot(ax=axes[1,5], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "PAT")
somm2_pie.plot(ax=axes[1,6], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "PIE")
somm2_pug.plot(ax=axes[2,0], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "PUG")
somm2_sar.plot(ax=axes[2,1], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "SAR")
somm2_sic.plot(ax=axes[2,2], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "SIC")
somm2_tos.plot(ax=axes[2,3], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "TOS")
somm2_umb.plot(ax=axes[2,4], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "UMB")
somm2_vda.plot(ax=axes[2,5], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "VDA")
somm2_ven.plot(ax=axes[2,6], x ='data_somministrazione', y='totale', kind = 'bar', legend = False, xlabel = '', title = "VEN")


plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'

#plt.savefig('regioni.png', dpi=300)
plt.show()

# %%
#fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})

fig, axes = plt.subplots(nrows=3, ncols=7,sharex=False, sharey=True, gridspec_kw={'hspace': 1.25, 'wspace': 0}, dpi = 200)


somm2_abr.plot(ax=axes[0,0], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "ABR")
somm2_bas.plot(ax=axes[0,1], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "BAS")
somm2_cal.plot(ax=axes[0,2], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "CAL")
somm2_cam.plot(ax=axes[0,3], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "CAM")
somm2_emr.plot(ax=axes[0,4], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "EMR")
somm2_fvg.plot(ax=axes[0,5], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "FVG")
somm2_laz.plot(ax=axes[0,6], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "LAZ")
somm2_lig.plot(ax=axes[1,0], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "LIG")
somm2_lom.plot(ax=axes[1,1], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "LOM")
somm2_mar.plot(ax=axes[1,2], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "MAR")
somm2_mol.plot(ax=axes[1,3], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "MOL")
somm2_pab.plot(ax=axes[1,4], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PAB")
somm2_pat.plot(ax=axes[1,5], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PAT")
somm2_pie.plot(ax=axes[1,6], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PIE")
somm2_pug.plot(ax=axes[2,0], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PUG")
somm2_sar.plot(ax=axes[2,1], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "SAR")
somm2_sic.plot(ax=axes[2,2], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "SIC")
somm2_tos.plot(ax=axes[2,3], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "TOS")
somm2_umb.plot(ax=axes[2,4], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "UMB")
somm2_vda.plot(ax=axes[2,5], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "VDA")
somm2_ven.plot(ax=axes[2,6], x ='data_somministrazione', y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "VEN")


plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'

#plt.savefig('regioni100.png', dpi=300)

# %%
vaccini
# Out:
#    area  dosi_somministrate  dosi_consegnate  percentuale_somministrazione  \
# 0   ABR               19160            35170                          54.5
# 1   BAS               11240            17265                          65.1
# 2   CAL               20553            48640                          42.3
# 3   CAM              113870           147955                          77.0
# 4   EMR              127416           165935                          76.8
# 5   FVG               35601            44335                          80.3
# 6   LAZ              135902           178690                          76.1
# 7   LIG               37140            65840                          56.4
# 8   LOM              218995           305820                          71.6
# 9   MAR               28531            39530                          72.2
# 10  MOL                6715            12335                          54.4
# ...

# %%
from datetime import datetime
import matplotlib.dates as mdates

ita = somm2_ita.set_index('data_somministrazione')
emr = somm2_emr.set_index('data_somministrazione')
ven = somm2_ven.set_index('data_somministrazione')
vda = somm2_vda.set_index('data_somministrazione')
lom = somm2_lom.set_index('data_somministrazione')
laz = somm2_laz.set_index('data_somministrazione')
lig = somm2_lig.set_index('data_somministrazione')
pie = somm2_pie.set_index('data_somministrazione')
sar = somm2_sar.set_index('data_somministrazione')
sic = somm2_sic.set_index('data_somministrazione')
tos = somm2_tos.set_index('data_somministrazione')
pug = somm2_pug.set_index('data_somministrazione')
abr = somm2_abr.set_index('data_somministrazione')
bas = somm2_bas.set_index('data_somministrazione')
cal = somm2_cal.set_index('data_somministrazione')
cam = somm2_cam.set_index('data_somministrazione')
mar = somm2_mar.set_index('data_somministrazione')
mol = somm2_mol.set_index('data_somministrazione')
fvg = somm2_fvg.set_index('data_somministrazione')
pat = somm2_pat.set_index('data_somministrazione')
pab = somm2_pab.set_index('data_somministrazione')
pie = somm2_pie.set_index('data_somministrazione')
umb = somm2_umb.set_index('data_somministrazione')

today = datetime.today().strftime('%Y-%m-%d')

idx = pd.date_range('2020-12-27', today)

mol.index = pd.DatetimeIndex(mol.index)
mol = mol.reindex(idx)
mol.index = mol.index.strftime('%d/%m/%Y')

emr.index = pd.DatetimeIndex(emr.index)
emr = emr.reindex(idx)
emr.index = emr.index.strftime('%d/%m/%Y')

ven.index = pd.DatetimeIndex(ven.index)
ven = ven.reindex(idx)
ven.index = ven.index.strftime('%d/%m/%Y')

vda.index = pd.DatetimeIndex(vda.index)
vda = vda.reindex(idx)
vda.index = vda.index.strftime('%d/%m/%Y')

pie.index = pd.DatetimeIndex(pie.index)
pie = pie.reindex(idx)
pie.index = pie.index.strftime('%d/%m/%Y')

pab.index = pd.DatetimeIndex(pab.index)
pab = pab.reindex(idx)
pab.index = pab.index.strftime('%d/%m/%Y')

pat.index = pd.DatetimeIndex(pat.index)
pat = pat.reindex(idx)
pat.index = pat.index.strftime('%d/%m/%Y')

fvg.index = pd.DatetimeIndex(fvg.index)
fvg = fvg.reindex(idx)
fvg.index = fvg.index.strftime('%d/%m/%Y')

mar.index = pd.DatetimeIndex(mar.index)
mar = mar.reindex(idx)
mar.index = mar.index.strftime('%d/%m/%Y')

abr.index = pd.DatetimeIndex(abr.index)
abr = abr.reindex(idx)
abr.index = abr.index.strftime('%d/%m/%Y')

bas.index = pd.DatetimeIndex(bas.index)
bas = bas.reindex(idx)
bas.index = bas.index.strftime('%d/%m/%Y')

cal.index = pd.DatetimeIndex(cal.index)
cal = cal.reindex(idx)
cal.index = cal.index.strftime('%d/%m/%Y')

cam.index = pd.DatetimeIndex(cam.index)
cam = cam.reindex(idx)
cam.index = cam.index.strftime('%d/%m/%Y')

lig.index = pd.DatetimeIndex(lig.index)
lig = lig.reindex(idx)
lig.index = lig.index.strftime('%d/%m/%Y')

laz.index = pd.DatetimeIndex(laz.index)
laz = laz.reindex(idx)
laz.index = laz.index.strftime('%d/%m/%Y')

lom.index = pd.DatetimeIndex(lom.index)
lom = lom.reindex(idx)
lom.index = lom.index.strftime('%d/%m/%Y')

sic.index = pd.DatetimeIndex(sic.index)
sic = sic.reindex(idx)
sic.index = sic.index.strftime('%d/%m/%Y')

sar.index = pd.DatetimeIndex(sar.index)
sar = sar.reindex(idx)
sar.index = sar.index.strftime('%d/%m/%Y')

tos.index = pd.DatetimeIndex(tos.index)
tos = tos.reindex(idx)
tos.index = tos.index.strftime('%d/%m/%Y')

pug.index = pd.DatetimeIndex(pug.index)
pug = pug.reindex(idx)
pug.index = pug.index.strftime('%d/%m/%Y')

umb.index = pd.DatetimeIndex(umb.index)
umb = umb.reindex(idx)
umb.index = umb.index.strftime('%d/%m/%Y')


lig.area.fillna(method='ffill', inplace = True )
bas.area.fillna(method='ffill', inplace = True )
umb.area.fillna(method='ffill', inplace = True )
fvg.area.fillna(method='ffill', inplace = True )
pug.area.fillna(method='ffill', inplace = True )
cal.area.fillna(method='ffill', inplace = True )
cam.area.fillna(method='ffill', inplace = True )
sic.area.fillna(method='ffill', inplace = True )
sar.area.fillna(method='ffill', inplace = True )
tos.area.fillna(method='ffill', inplace = True )
mar.area.fillna(method='ffill', inplace = True )
mol.area.fillna(method='ffill', inplace = True )
abr.area.fillna(method='ffill', inplace = True )
emr.area.fillna(method='ffill', inplace = True )
lom.area.fillna(method='ffill', inplace = True )
laz.area.fillna(method='ffill', inplace = True )
pab.area.fillna(method='ffill', inplace = True )
pat.area.fillna(method='ffill', inplace = True )
pie.area.fillna(method='ffill', inplace = True )
ven.area.fillna(method='ffill', inplace = True )
vda.area.fillna(method='ffill', inplace = True )
ita.area.fillna(method='ffill', inplace = True )

# %%
fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.275, 'wspace': 0.})

#fig, axes = plt.subplots(nrows=3, ncols=7,sharex=False, sharey=True, gridspec_kw={'hspace': 1.25, 'wspace': 0}, dpi = 200)


abr.plot(ax=axes[0,0], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "ABR")
bas.plot(ax=axes[0,1], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "BAS")
cal.plot(ax=axes[0,2], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "CAL")
cam.plot(ax=axes[0,3], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "CAM")
emr.plot(ax=axes[0,4], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "EMR")
fvg.plot(ax=axes[0,5], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "FVG")
laz.plot(ax=axes[0,6], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "LAZ")
lig.plot(ax=axes[1,0], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "LIG")
lom.plot(ax=axes[1,1], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "LOM")
mar.plot(ax=axes[1,2], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "MAR")
mol.plot(ax=axes[1,3], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "MOL")
pab.plot(ax=axes[1,4], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PAB")
pat.plot(ax=axes[1,5], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PAT")
pie.plot(ax=axes[1,6], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PIE")
pug.plot(ax=axes[2,0], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PUG")
sar.plot(ax=axes[2,1], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "SAR")
sic.plot(ax=axes[2,2], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "SIC")
tos.plot(ax=axes[2,3], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "TOS")
umb.plot(ax=axes[2,4], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "UMB")
vda.plot(ax=axes[2,5], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "VDA")
ven.plot(ax=axes[2,6], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "VEN")

#fig.autofmt_xdate()
fig.suptitle("Vaccinati per 1000 abitanti", fontsize=14)
plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'

axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))

#plt.savefig('regioni100.png', dpi=300)

# %%
#fig, axes = plt.subplots(nrows=3, ncols=7,sharex=False, sharey=True, gridspec_kw={'hspace': 1.25, 'wspace': 0}, dpi = 200)


fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.275, 'wspace': 0.})

abr.plot(ax=axes[0,0], y='totale', kind = 'bar', legend = False, xlabel = '', title = "ABR")
bas.plot(ax=axes[0,1], y='totale', kind = 'bar', legend = False, xlabel = '', title = "BAS")
cal.plot(ax=axes[0,2], y='totale', kind = 'bar', legend = False, xlabel = '', title = "CAL")
cam.plot(ax=axes[0,3], y='totale', kind = 'bar', legend = False, xlabel = '', title = "CAM")
emr.plot(ax=axes[0,4], y='totale', kind = 'bar', legend = False, xlabel = '', title = "EMR")
fvg.plot(ax=axes[0,5], y='totale', kind = 'bar', legend = False, xlabel = '', title = "FVG")
laz.plot(ax=axes[0,6], y='totale', kind = 'bar', legend = False, xlabel = '', title = "LAZ")
lig.plot(ax=axes[1,0], y='totale', kind = 'bar', legend = False, xlabel = '', title = "LIG")
lom.plot(ax=axes[1,1], y='totale', kind = 'bar', legend = False, xlabel = '', title = "LOM")
mar.plot(ax=axes[1,2], y='totale', kind = 'bar', legend = False, xlabel = '', title = "MAR")
mol.plot(ax=axes[1,3], y='totale', kind = 'bar', legend = False, xlabel = '', title = "MOL")
pab.plot(ax=axes[1,4], y='totale', kind = 'bar', legend = False, xlabel = '', title = "PAB")
pat.plot(ax=axes[1,5], y='totale', kind = 'bar', legend = False, xlabel = '', title = "PAT")
pie.plot(ax=axes[1,6], y='totale', kind = 'bar', legend = False, xlabel = '', title = "PIE")
pug.plot(ax=axes[2,0], y='totale', kind = 'bar', legend = False, xlabel = '', title = "PUG")
sar.plot(ax=axes[2,1], y='totale', kind = 'bar', legend = False, xlabel = '', title = "SAR")
sic.plot(ax=axes[2,2], y='totale', kind = 'bar', legend = False, xlabel = '', title = "SIC")
tos.plot(ax=axes[2,3], y='totale', kind = 'bar', legend = False, xlabel = '', title = "TOS")
umb.plot(ax=axes[2,4], y='totale', kind = 'bar', legend = False, xlabel = '', title = "UMB")
vda.plot(ax=axes[2,5], y='totale', kind = 'bar', legend = False, xlabel = '', title = "VDA")
ven.plot(ax=axes[2,6], y='totale', kind = 'bar', legend = False, xlabel = '', title = "VEN")


axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))


plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
fig.suptitle("Vaccinati per regione", fontsize=14)
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')


plt.savefig('RegioniAssoluto.png', dpi=300)

# %%
plt.figure()
ax = plt.gca()
ita.plot( y='per_1000', kind = 'bar', title = "italia per 1000", xlabel = '')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.rcParams['font.size'] = '8'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.legend(loc="upper left")
plt.xticks(rotation=30)
plt.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='top', rotation='0')

plt.savefig('Italia_Giorn_1000.png', dpi=300)

# %%
ita['cumulativa'] = ita['totale'].cumsum()
emr['cumulativa'] = emr['totale'].cumsum()
ven['cumulativa'] = ven['totale'].cumsum()
abr['cumulativa'] = abr['totale'].cumsum()
bas['cumulativa'] = bas['totale'].cumsum()
cal['cumulativa'] = cal['totale'].cumsum()
cam['cumulativa'] = cam['totale'].cumsum()
fvg['cumulativa'] = fvg['totale'].cumsum()
laz['cumulativa'] = laz['totale'].cumsum()
lom['cumulativa'] = lom['totale'].cumsum()
mar['cumulativa'] = mar['totale'].cumsum()
mol['cumulativa'] = mol['totale'].cumsum()
pab['cumulativa'] = pab['totale'].cumsum()
pat['cumulativa'] = pat['totale'].cumsum()
pie['cumulativa'] = pie['totale'].cumsum()
pug['cumulativa'] = pug['totale'].cumsum()
sar['cumulativa'] = sar['totale'].cumsum()
sic['cumulativa'] = sic['totale'].cumsum()
tos['cumulativa'] = tos['totale'].cumsum()
umb['cumulativa'] = umb['totale'].cumsum()
vda['cumulativa'] = vda['totale'].cumsum()
lig['cumulativa'] = lig['totale'].cumsum()

ita['cumulativa_prima'] = ita['prima_dose'].cumsum()
emr['cumulativa_prima'] = emr['prima_dose'].cumsum()
ven['cumulativa_prima'] = ven['prima_dose'].cumsum()
abr['cumulativa_prima'] = abr['prima_dose'].cumsum()
bas['cumulativa_prima'] = bas['prima_dose'].cumsum()
cal['cumulativa_prima'] = cal['prima_dose'].cumsum()
cam['cumulativa_prima'] = cam['prima_dose'].cumsum()
fvg['cumulativa_prima'] = fvg['prima_dose'].cumsum()
laz['cumulativa_prima'] = laz['prima_dose'].cumsum()
lom['cumulativa_prima'] = lom['prima_dose'].cumsum()
mar['cumulativa_prima'] = mar['prima_dose'].cumsum()
mol['cumulativa_prima'] = mol['prima_dose'].cumsum()
pab['cumulativa_prima'] = pab['prima_dose'].cumsum()
pat['cumulativa_prima'] = pat['prima_dose'].cumsum()
pie['cumulativa_prima'] = pie['prima_dose'].cumsum()
pug['cumulativa_prima'] = pug['prima_dose'].cumsum()
sar['cumulativa_prima'] = sar['prima_dose'].cumsum()
sic['cumulativa_prima'] = sic['prima_dose'].cumsum()
tos['cumulativa_prima'] = tos['prima_dose'].cumsum()
umb['cumulativa_prima'] = umb['prima_dose'].cumsum()
vda['cumulativa_prima'] = vda['prima_dose'].cumsum()
lig['cumulativa_prima'] = lig['prima_dose'].cumsum()

ita['cumulativa_seconda'] = ita['seconda_dose'].cumsum()
emr['cumulativa_seconda'] = emr['seconda_dose'].cumsum()
ven['cumulativa_seconda'] = ven['seconda_dose'].cumsum()
abr['cumulativa_seconda'] = abr['seconda_dose'].cumsum()
bas['cumulativa_seconda'] = bas['seconda_dose'].cumsum()
cal['cumulativa_seconda'] = cal['seconda_dose'].cumsum()
cam['cumulativa_seconda'] = cam['seconda_dose'].cumsum()
fvg['cumulativa_seconda'] = fvg['seconda_dose'].cumsum()
laz['cumulativa_seconda'] = laz['seconda_dose'].cumsum()
lom['cumulativa_seconda'] = lom['seconda_dose'].cumsum()
mar['cumulativa_seconda'] = mar['seconda_dose'].cumsum()
mol['cumulativa_seconda'] = mol['seconda_dose'].cumsum()
pab['cumulativa_seconda'] = pab['seconda_dose'].cumsum()
pat['cumulativa_seconda'] = pat['seconda_dose'].cumsum()
pie['cumulativa_seconda'] = pie['seconda_dose'].cumsum()
pug['cumulativa_seconda'] = pug['seconda_dose'].cumsum()
sar['cumulativa_seconda'] = sar['seconda_dose'].cumsum()
sic['cumulativa_seconda'] = sic['seconda_dose'].cumsum()
tos['cumulativa_seconda'] = tos['seconda_dose'].cumsum()
umb['cumulativa_seconda'] = umb['seconda_dose'].cumsum()
vda['cumulativa_seconda'] = vda['seconda_dose'].cumsum()
lig['cumulativa_seconda'] = lig['seconda_dose'].cumsum()



ita.cumulativa.fillna(method='ffill', inplace = True )
emr.cumulativa.fillna(method='ffill', inplace = True )
ven.cumulativa.fillna(method='ffill', inplace = True )
abr.cumulativa.fillna(method='ffill', inplace = True )
bas.cumulativa.fillna(method='ffill', inplace = True )
cal.cumulativa.fillna(method='ffill', inplace = True )
cam.cumulativa.fillna(method='ffill', inplace = True )
fvg.cumulativa.fillna(method='ffill', inplace = True )
laz.cumulativa.fillna(method='ffill', inplace = True )
lom.cumulativa.fillna(method='ffill', inplace = True )
lig.cumulativa.fillna(method='ffill', inplace = True )
mar.cumulativa.fillna(method='ffill', inplace = True )
mol.cumulativa.fillna(method='ffill', inplace = True )
pab.cumulativa.fillna(method='ffill', inplace = True )
pat.cumulativa.fillna(method='ffill', inplace = True )
pie.cumulativa.fillna(method='ffill', inplace = True )
pug.cumulativa.fillna(method='ffill', inplace = True )
sar.cumulativa.fillna(method='ffill', inplace = True )
sic.cumulativa.fillna(method='ffill', inplace = True )
tos.cumulativa.fillna(method='ffill', inplace = True )
umb.cumulativa.fillna(method='ffill', inplace = True )
vda.cumulativa.fillna(method='ffill', inplace = True )


ita.cumulativa_prima.fillna(method='ffill', inplace = True )
emr.cumulativa_prima.fillna(method='ffill', inplace = True )
ven.cumulativa_prima.fillna(method='ffill', inplace = True )
abr.cumulativa_prima.fillna(method='ffill', inplace = True )
bas.cumulativa_prima.fillna(method='ffill', inplace = True )
cal.cumulativa_prima.fillna(method='ffill', inplace = True )
cam.cumulativa_prima.fillna(method='ffill', inplace = True )
fvg.cumulativa_prima.fillna(method='ffill', inplace = True )
laz.cumulativa_prima.fillna(method='ffill', inplace = True )
lom.cumulativa_prima.fillna(method='ffill', inplace = True )
lig.cumulativa_prima.fillna(method='ffill', inplace = True )
mar.cumulativa_prima.fillna(method='ffill', inplace = True )
mol.cumulativa_prima.fillna(method='ffill', inplace = True )
pab.cumulativa_prima.fillna(method='ffill', inplace = True )
pat.cumulativa_prima.fillna(method='ffill', inplace = True )
pie.cumulativa_prima.fillna(method='ffill', inplace = True )
pug.cumulativa_prima.fillna(method='ffill', inplace = True )
sar.cumulativa_prima.fillna(method='ffill', inplace = True )
sic.cumulativa_prima.fillna(method='ffill', inplace = True )
tos.cumulativa_prima.fillna(method='ffill', inplace = True )
umb.cumulativa_prima.fillna(method='ffill', inplace = True )
vda.cumulativa_prima.fillna(method='ffill', inplace = True )



ita.cumulativa_seconda.fillna(method='ffill', inplace = True )
emr.cumulativa_seconda.fillna(method='ffill', inplace = True )
ven.cumulativa_seconda.fillna(method='ffill', inplace = True )
abr.cumulativa_seconda.fillna(method='ffill', inplace = True )
bas.cumulativa_seconda.fillna(method='ffill', inplace = True )
cal.cumulativa_seconda.fillna(method='ffill', inplace = True )
cam.cumulativa_seconda.fillna(method='ffill', inplace = True )
fvg.cumulativa_seconda.fillna(method='ffill', inplace = True )
laz.cumulativa_seconda.fillna(method='ffill', inplace = True )
lom.cumulativa_seconda.fillna(method='ffill', inplace = True )
lig.cumulativa_seconda.fillna(method='ffill', inplace = True )
mar.cumulativa_seconda.fillna(method='ffill', inplace = True )
mol.cumulativa_seconda.fillna(method='ffill', inplace = True )
pab.cumulativa_seconda.fillna(method='ffill', inplace = True )
pat.cumulativa_seconda.fillna(method='ffill', inplace = True )
pie.cumulativa_seconda.fillna(method='ffill', inplace = True )
pug.cumulativa_seconda.fillna(method='ffill', inplace = True )
sar.cumulativa_seconda.fillna(method='ffill', inplace = True )
sic.cumulativa_seconda.fillna(method='ffill', inplace = True )
tos.cumulativa_seconda.fillna(method='ffill', inplace = True )
umb.cumulativa_seconda.fillna(method='ffill', inplace = True )
vda.cumulativa_seconda.fillna(method='ffill', inplace = True )


ita['cumulativa_1000']       = ita['cumulativa'] / 60360
emr['cumulativa_1000']       = emr['cumulativa'] / 4459
ven['cumulativa_1000']       = ven['cumulativa'] / 4906
abr['cumulativa_1000']       = abr['cumulativa'] / 1312
bas['cumulativa_1000']       = bas['cumulativa'] / 562.869
cal['cumulativa_1000']       = cal['cumulativa'] / 1947
cam['cumulativa_1000']       = cam['cumulativa'] / 5802
fvg['cumulativa_1000']       = fvg['cumulativa'] / 1215
laz['cumulativa_1000']       = laz['cumulativa'] / 5879
lom['cumulativa_1000']       = lom['cumulativa'] / 10060
lig['cumulativa_1000']       = lig['cumulativa'] / 1551
mar['cumulativa_1000']       = mar['cumulativa'] / 1525
mol['cumulativa_1000']       = mol['cumulativa'] / 305.617
pab['cumulativa_1000']       = pab['cumulativa'] / 520.891
pat['cumulativa_1000']       = pat['cumulativa'] / 739.139
pie['cumulativa_1000']       = pie['cumulativa'] / 4356
pug['cumulativa_1000']       = pug['cumulativa'] / 4029
sar['cumulativa_1000']       = sar['cumulativa'] / 1640
sic['cumulativa_1000']       = sic['cumulativa'] / 5000
tos['cumulativa_1000']       = tos['cumulativa'] / 3730
umb['cumulativa_1000']       = umb['cumulativa'] / 882.015
vda['cumulativa_1000']       = vda['cumulativa'] / 125.666



ita['cumulativa_prima_1000']       = ita['cumulativa_prima'] / 60360
emr['cumulativa_prima_1000']       = emr['cumulativa_prima'] / 4459
ven['cumulativa_prima_1000']       = ven['cumulativa_prima'] / 4906
abr['cumulativa_prima_1000']       = abr['cumulativa_prima'] / 1312
bas['cumulativa_prima_1000']       = bas['cumulativa_prima'] / 562.869
cal['cumulativa_prima_1000']       = cal['cumulativa_prima'] / 1947
cam['cumulativa_prima_1000']       = cam['cumulativa_prima'] / 5802
fvg['cumulativa_prima_1000']       = fvg['cumulativa_prima'] / 1215
laz['cumulativa_prima_1000']       = laz['cumulativa_prima'] / 5879
lom['cumulativa_prima_1000']       = lom['cumulativa_prima'] / 10060
lig['cumulativa_prima_1000']       = lig['cumulativa_prima'] / 1551
mar['cumulativa_prima_1000']       = mar['cumulativa_prima'] / 1525
mol['cumulativa_prima_1000']       = mol['cumulativa_prima'] / 305.617
pab['cumulativa_prima_1000']       = pab['cumulativa_prima'] / 520.891
pat['cumulativa_prima_1000']       = pat['cumulativa_prima'] / 739.139
pie['cumulativa_prima_1000']       = pie['cumulativa_prima'] / 4356
pug['cumulativa_prima_1000']       = pug['cumulativa_prima'] / 4029
sar['cumulativa_prima_1000']       = sar['cumulativa_prima'] / 1640
sic['cumulativa_prima_1000']       = sic['cumulativa_prima'] / 5000
tos['cumulativa_prima_1000']       = tos['cumulativa_prima'] / 3730
umb['cumulativa_prima_1000']       = umb['cumulativa_prima'] / 882.015
vda['cumulativa_prima_1000']       = vda['cumulativa_prima'] / 125.666

ita['cumulativa_seconda_1000']       = ita['cumulativa_seconda'] / 60360
emr['cumulativa_seconda_1000']       = emr['cumulativa_seconda'] / 4459
ven['cumulativa_seconda_1000']       = ven['cumulativa_seconda'] / 4906
abr['cumulativa_seconda_1000']       = abr['cumulativa_seconda'] / 1312
bas['cumulativa_seconda_1000']       = bas['cumulativa_seconda'] / 562.869
cal['cumulativa_seconda_1000']       = cal['cumulativa_seconda'] / 1947
cam['cumulativa_seconda_1000']       = cam['cumulativa_seconda'] / 5802
fvg['cumulativa_seconda_1000']       = fvg['cumulativa_seconda'] / 1215
laz['cumulativa_seconda_1000']       = laz['cumulativa_seconda'] / 5879
lom['cumulativa_seconda_1000']       = lom['cumulativa_seconda'] / 10060
lig['cumulativa_seconda_1000']       = lig['cumulativa_seconda'] / 1551
mar['cumulativa_seconda_1000']       = mar['cumulativa_seconda'] / 1525
mol['cumulativa_seconda_1000']       = mol['cumulativa_seconda'] / 305.617
pab['cumulativa_seconda_1000']       = pab['cumulativa_seconda'] / 520.891
pat['cumulativa_seconda_1000']       = pat['cumulativa_seconda'] / 739.139
pie['cumulativa_seconda_1000']       = pie['cumulativa_seconda'] / 4356
pug['cumulativa_seconda_1000']       = pug['cumulativa_seconda'] / 4029
sar['cumulativa_seconda_1000']       = sar['cumulativa_seconda'] / 1640
sic['cumulativa_seconda_1000']       = sic['cumulativa_seconda'] / 5000
tos['cumulativa_seconda_1000']       = tos['cumulativa_seconda'] / 3730
umb['cumulativa_seconda_1000']       = umb['cumulativa_seconda'] / 882.015
vda['cumulativa_seconda_1000']       = vda['cumulativa_seconda'] / 125.666

# %%
plt.figure()
ax = plt.gca()
ita.plot( y='cumulativa_1000', kind = 'bar', title = "italia per 1000", xlabel = '')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.rcParams['font.size'] = '8'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.legend(loc="upper left")
plt.xticks(rotation=30)

plt.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='top', rotation='0')
plt.savefig('Italia_Cum_1000.png', dpi=300)

# %%
#%matplotlib widget 
#per plot interattivi
fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})


plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
abr.plot(ax=axes[0,0], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "ABR")
bas.plot(ax=axes[0,1], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "BAS")
cal.plot(ax=axes[0,2], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "CAL")
cam.plot(ax=axes[0,3], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "CAM")
emr.plot(ax=axes[0,4], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "EMR")
fvg.plot(ax=axes[0,5], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "FVG")
laz.plot(ax=axes[0,6], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "LAZ")
lig.plot(ax=axes[1,0], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "LIG")
lom.plot(ax=axes[1,1], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "LOM")
mar.plot(ax=axes[1,2], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "MAR")
mol.plot(ax=axes[1,3], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "MOL")
pab.plot(ax=axes[1,4], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "PAB")
pat.plot(ax=axes[1,5], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "PAT")
pie.plot(ax=axes[1,6], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "PIE")
pug.plot(ax=axes[2,0], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "PUG")
sar.plot(ax=axes[2,1], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "SAR")
sic.plot(ax=axes[2,2], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "SIC")
tos.plot(ax=axes[2,3], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "TOS")
umb.plot(ax=axes[2,4], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "UMB")
vda.plot(ax=axes[2,5], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "VDA")
ven.plot(ax=axes[2,6], y='cumulativa_1000', kind = 'bar', legend = False, xlabel = '', title = "VEN")


axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'


axes[0,0].set_title('ABR', y=1.05, pad=0)
axes[0,1].set_title('BAS', y=1.05, pad=0)
axes[0,2].set_title('CAL', y=1.05, pad=0)
axes[0,3].set_title('CAM', y=1.05, pad=0)
axes[0,4].set_title('EMR', y=1.05, pad=0)
axes[0,5].set_title('FVG', y=1.05, pad=0)
axes[0,6].set_title('LAZ', y=1.05, pad=0)
axes[1,0].set_title('LIG', y=1.05, pad=0)
axes[1,1].set_title('LOM', y=1.05, pad=0)
axes[1,2].set_title('MAR', y=1.05, pad=0)
axes[1,3].set_title('MOL', y=1.05, pad=0)
axes[1,4].set_title('PAB', y=1.05, pad=0)
axes[1,5].set_title('PAT', y=1.05, pad=0)
axes[1,6].set_title('PIE', y=1.05, pad=0)
axes[2,0].set_title('PUG', y=1.05, pad=0)
axes[2,1].set_title('SAR', y=1.05, pad=0)
axes[2,2].set_title('SIC', y=1.05, pad=0)
axes[2,3].set_title('TOS', y=1.05, pad=0)
axes[2,4].set_title('UMB', y=1.05, pad=0)
axes[2,5].set_title('VDA', y=1.05, pad=0)
axes[2,6].set_title('VEN', y=1.05, pad=0)

fig.suptitle("Vaccinati per regione, per 1000 abitanti", fontsize=11)
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Regioni_Cum_1000.png', dpi=300)
plt.show()

# %%
ita['avg'] = ita['totale'].rolling(window=7, min_periods=2).mean()

plt.figure()
ax = plt.gca()
ita.plot( y='totale', kind = 'bar',  title = "italia", ax = ax, xlabel = '' )
ita.plot( y='avg',    kind = 'line', color = 'orange', ax = ax, xlabel = '' )
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.rcParams['font.size'] = '8'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.legend(loc="upper left")
plt.xticks(rotation=20)
plt.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='top', rotation='0')

plt.savefig('Italia_Giorn_Tot.png', dpi=300)

# %%
emr
# Out:
#            area   totale  sesso_maschile  sesso_femminile  \
# 27/12/2020  EMR    964.0           372.0            592.0
# 28/12/2020  EMR      NaN             NaN              NaN
# 29/12/2020  EMR      NaN             NaN              NaN
# 30/12/2020  EMR      NaN             NaN              NaN
# 31/12/2020  EMR   2103.0           744.0           1359.0
# 01/01/2021  EMR      NaN             NaN              NaN
# 02/01/2021  EMR   2270.0           890.0           1380.0
# 03/01/2021  EMR   2726.0           934.0           1792.0
# 04/01/2021  EMR   7197.0          2496.0           4701.0
# 05/01/2021  EMR   9039.0          3080.0           5959.0
# 06/01/2021  EMR   8143.0          2907.0           5236.0
# 07/01/2021  EMR   9798.0          3278.0           6520.0
# 08/01/2021  EMR  10319.0          3428.0           6891.0
# 09/01/2021  EMR   9257.0          3236.0           6021.0
# 10/01/2021  EMR   6839.0          2565.0           4274.0
# ...

# %%
somm1_grouped = somm1.groupby(somm1.area)
somm1_emr     = somm1_grouped.get_group('EMR')
somm1_ven     = somm1_grouped.get_group('VEN')
somm1_abr     = somm1_grouped.get_group('ABR')
somm1_bas     = somm1_grouped.get_group('BAS')
somm1_cal     = somm1_grouped.get_group('CAL')
somm1_cam     = somm1_grouped.get_group('CAM')
somm1_fvg     = somm1_grouped.get_group('FVG')
somm1_laz     = somm1_grouped.get_group('LAZ')
somm1_lom     = somm1_grouped.get_group('LOM')
somm1_lig     = somm1_grouped.get_group('LIG')
somm1_mar     = somm1_grouped.get_group('MAR')
somm1_mol     = somm1_grouped.get_group('MOL')
somm1_pab     = somm1_grouped.get_group('PAB')
somm1_pat     = somm1_grouped.get_group('PAT')
somm1_pie     = somm1_grouped.get_group('PIE')
somm1_pug     = somm1_grouped.get_group('PUG')
somm1_sar     = somm1_grouped.get_group('SAR')
somm1_sic     = somm1_grouped.get_group('SIC')
somm1_tos     = somm1_grouped.get_group('TOS')
somm1_umb     = somm1_grouped.get_group('UMB')
somm1_vda     = somm1_grouped.get_group('VDA')

somm1_emr['totale'] = somm1_emr['sesso_maschile'] + somm1_emr['sesso_femminile']
somm1_tos['totale'] = somm1_tos['sesso_maschile'] + somm1_tos['sesso_femminile']
somm1_vda['totale'] = somm1_vda['sesso_maschile'] + somm1_vda['sesso_femminile']
somm1_ven['totale'] = somm1_ven['sesso_maschile'] + somm1_ven['sesso_femminile']
somm1_umb['totale'] = somm1_umb['sesso_maschile'] + somm1_umb['sesso_femminile']
somm1_sic['totale'] = somm1_sic['sesso_maschile'] + somm1_sic['sesso_femminile']
somm1_sar['totale'] = somm1_sar['sesso_maschile'] + somm1_sar['sesso_femminile']
somm1_pug['totale'] = somm1_pug['sesso_maschile'] + somm1_pug['sesso_femminile']
somm1_pie['totale'] = somm1_pie['sesso_maschile'] + somm1_pie['sesso_femminile']
somm1_pat['totale'] = somm1_pat['sesso_maschile'] + somm1_pat['sesso_femminile']
somm1_pab['totale'] = somm1_pab['sesso_maschile'] + somm1_pab['sesso_femminile']
somm1_mol['totale'] = somm1_mol['sesso_maschile'] + somm1_mol['sesso_femminile']
somm1_mar['totale'] = somm1_mar['sesso_maschile'] + somm1_mar['sesso_femminile']
somm1_lig['totale'] = somm1_lig['sesso_maschile'] + somm1_lig['sesso_femminile']
somm1_lom['totale'] = somm1_lom['sesso_maschile'] + somm1_lom['sesso_femminile']
somm1_laz['totale'] = somm1_laz['sesso_maschile'] + somm1_laz['sesso_femminile']
somm1_fvg['totale'] = somm1_fvg['sesso_maschile'] + somm1_fvg['sesso_femminile']
somm1_cam['totale'] = somm1_cam['sesso_maschile'] + somm1_cam['sesso_femminile']
somm1_cal['totale'] = somm1_cal['sesso_maschile'] + somm1_cal['sesso_femminile']
somm1_bas['totale'] = somm1_bas['sesso_maschile'] + somm1_bas['sesso_femminile']
somm1_abr['totale'] = somm1_abr['sesso_maschile'] + somm1_abr['sesso_femminile']
somm1_emr
# Out:
# <ipython-input-109-dcec7ca3dbbb>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   somm1_emr['totale'] = somm1_emr['sesso_maschile'] + somm1_emr['sesso_femminile']
# <ipython-input-109-dcec7ca3dbbb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   somm1_tos['totale'] = somm1_tos['sesso_maschile'] + somm1_tos['sesso_femminile']
# <ipython-input-109-dcec7ca3dbbb>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
anag
# Out:
#   fascia_anagrafica  totale  sesso_maschile  sesso_femminile  \
# 0             16-19    1326             591              735
# 1             20-29  137697           46370            91327
# 2             30-39  210154           82195           127959
# 3             40-49  263176           85637           177539
# 4             50-59  353575          115325           238250
# 5             60-69  217150          111428           105722
# 6             70-79   47355           29359            17996
# 7             80-89   67690           20942            46748
# 8               90+   52230            8192            44038
#
#    categoria_operatori_sanitari_sociosanitari  \
# 0                                         482
# 1                                      100684
# 2                                      160302
# 3                                      191900
# 4                                      251482
# 5                                      154481
# ...

# %%
# %matplotlib widget
# %matplotlib inline
plt.figure()
ax = plt.gca()
anag.groupby(['fascia_anagrafica']).sum().plot(kind='pie', y='totale', legend = False)
plt.rcParams['font.size'] = '8'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
#plt.legend(loc="upper left")
plt.xticks(rotation=30)
plt.text(0.9, 0.05, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Torta_Totale.png', dpi=300)

# %%
# %matplotlib inline

# %%
somm1_emr
# Out:
#      data_somministrazione        fornitore area fascia_anagrafica  \
# 27              2020-12-27  Pfizer/BioNTech  EMR             20-29
# 28              2020-12-27  Pfizer/BioNTech  EMR             30-39
# 29              2020-12-27  Pfizer/BioNTech  EMR             40-49
# 30              2020-12-27  Pfizer/BioNTech  EMR             50-59
# 31              2020-12-27  Pfizer/BioNTech  EMR             60-69
# ...                    ...              ...  ...               ...
# 4365            2021-01-23  Pfizer/BioNTech  EMR             50-59
# 4366            2021-01-23  Pfizer/BioNTech  EMR             60-69
# 4367            2021-01-23  Pfizer/BioNTech  EMR             70-79
# 4368            2021-01-23  Pfizer/BioNTech  EMR             80-89
# 4369            2021-01-23  Pfizer/BioNTech  EMR               90+
#
#       sesso_maschile  sesso_femminile  \
# 27                52               86
# 28                57               82
# 29                80              145
# ...

# %%
vaccinisort = vaccini.sort_values(by = 'percentuale_somministrazione')
vaccinisort.plot(kind='barh',x = 'area', y='percentuale_somministrazione', legend = False)

plt.title("Regioni per percentuale di somministrazioni")
#plt.savefig('barreitaliaperc.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Regioni per percentuale di somministrazioni')

# %%
from datetime import date, timedelta
yesterday = (date.today() - timedelta(days=1)).strftime('%Y-%m-%d')
today = date.today().strftime('%Y-%m-%d')

emroggi = emr.iloc[-1]
venoggi = ven.iloc[-1]
umboggi = umb.iloc[-1]
vdaoggi = vda.iloc[-1]
tosoggi = tos.iloc[-1]
sicoggi = sic.iloc[-1]
saroggi = sar.iloc[-1]
pugoggi = pug.iloc[-1]
pieoggi = pie.iloc[-1]
patoggi = pat.iloc[-1]
paboggi = pab.iloc[-1]
mologgi = mol.iloc[-1]
lomoggi = lom.iloc[-1]
lazoggi = laz.iloc[-1]
ligoggi = lig.iloc[-1]
camoggi = cam.iloc[-1]
caloggi = cal.iloc[-1]
maroggi = mar.iloc[-1]
fvgoggi = fvg.iloc[-1]
basoggi = bas.iloc[-1]
abroggi = abr.iloc[-1]

cum = pd.DataFrame([emroggi, venoggi, umboggi, vdaoggi, tosoggi, sicoggi, saroggi, pugoggi, pieoggi,
                    patoggi, mologgi, lomoggi, ligoggi, lazoggi, camoggi, caloggi, maroggi, fvgoggi,
                    basoggi, abroggi, paboggi])
cum
# Out:
#            area  totale  sesso_maschile  sesso_femminile  \
# 24/01/2021  EMR     NaN             NaN              NaN
# 24/01/2021  VEN     NaN             NaN              NaN
# 24/01/2021  UMB     NaN             NaN              NaN
# 24/01/2021  VDA     NaN             NaN              NaN
# 24/01/2021  TOS     NaN             NaN              NaN
# 24/01/2021  SIC     NaN             NaN              NaN
# 24/01/2021  SAR     NaN             NaN              NaN
# 24/01/2021  PUG     NaN             NaN              NaN
# 24/01/2021  PIE     NaN             NaN              NaN
# 24/01/2021  PAT     NaN             NaN              NaN
# 24/01/2021  MOL     NaN             NaN              NaN
# 24/01/2021  LOM     NaN             NaN              NaN
# 24/01/2021  LIG     NaN             NaN              NaN
# 24/01/2021  LAZ     NaN             NaN              NaN
# 24/01/2021  CAM     NaN             NaN              NaN
# ...

# %%
cum.plot(kind='barh',x = 'area', y='cumulativa_1000', legend = False)
# Out:
# <AxesSubplot:ylabel='area'>

# %%
cum = cum.sort_values(by = 'cumulativa_1000')
cum.plot(kind='barh',x = 'area', y='cumulativa_1000', legend = False)

plt.title("Regioni per dosi somministrate per 1000 abitanti")
#plt.savefig('barreitalia.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Regioni per dosi somministrate per 1000 abitanti')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, dpi = 200, gridspec_kw={ 'wspace': 0.25})

plt.rcParams['font.size'] = '4'
cum.plot(        ax=axes[0],x = 'area', y='cumulativa_1000', kind = 'barh', legend = False, xlabel = '', title = "Dosi somministrate per 1000 abitanti")
vaccinisort.plot(ax=axes[1],x = 'area', y='percentuale_somministrazione', kind = 'barh', legend = False, xlabel = '', title = "Percentuale dosi somministrate")



plt.text(0.9, 0.05, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')
plt.savefig('Barre_Regioni.png', dpi=300)
plt.show()

# %%
cum
# Out:
#            area  totale  sesso_maschile  sesso_femminile  \
# 24/01/2021  CAL     NaN             NaN              NaN
# 24/01/2021  ABR     NaN             NaN              NaN
# 24/01/2021  SAR     NaN             NaN              NaN
# 24/01/2021  UMB     NaN             NaN              NaN
# 24/01/2021  PUG     NaN             NaN              NaN
# 24/01/2021  MAR     NaN             NaN              NaN
# 24/01/2021  SIC     NaN             NaN              NaN
# 24/01/2021  PAT     NaN             NaN              NaN
# 24/01/2021  CAM     NaN             NaN              NaN
# 24/01/2021  BAS     NaN             NaN              NaN
# 24/01/2021  LOM     NaN             NaN              NaN
# 24/01/2021  MOL     NaN             NaN              NaN
# 24/01/2021  TOS     NaN             NaN              NaN
# 24/01/2021  LAZ     NaN             NaN              NaN
# 24/01/2021  LIG     NaN             NaN              NaN
# ...

# %%
cons_grouped = cons.groupby(cons.area)
cons_emr     = cons_grouped.get_group('EMR')
cons_ven     = cons_grouped.get_group('VEN')
cons_abr     = cons_grouped.get_group('ABR')
cons_bas     = cons_grouped.get_group('BAS')
cons_cal     = cons_grouped.get_group('CAL')
cons_cam     = cons_grouped.get_group('CAM')
cons_fvg     = cons_grouped.get_group('FVG')
cons_laz     = cons_grouped.get_group('LAZ')
cons_lom     = cons_grouped.get_group('LOM')
cons_lig     = cons_grouped.get_group('LIG')
cons_mar     = cons_grouped.get_group('MAR')
cons_mol     = cons_grouped.get_group('MOL')
cons_pab     = cons_grouped.get_group('PAB')
cons_pat     = cons_grouped.get_group('PAT')
cons_pie     = cons_grouped.get_group('PIE')
cons_pug     = cons_grouped.get_group('PUG')
cons_sar     = cons_grouped.get_group('SAR')
cons_sic     = cons_grouped.get_group('SIC')
cons_tos     = cons_grouped.get_group('TOS')
cons_umb     = cons_grouped.get_group('UMB')
cons_vda     = cons_grouped.get_group('VDA')

cons_emr['per_1000']       = cons_emr['numero_dosi'] / 4459
cons_ven['per_1000']       = cons_ven['numero_dosi'] / 4906
cons_abr['per_1000']       = cons_abr['numero_dosi'] / 1312
cons_bas['per_1000']       = cons_bas['numero_dosi'] / 562.869
cons_cal['per_1000']       = cons_cal['numero_dosi'] / 1947
cons_cam['per_1000']       = cons_cam['numero_dosi'] / 5802
cons_fvg['per_1000']       = cons_fvg['numero_dosi'] / 1215
cons_laz['per_1000']       = cons_laz['numero_dosi'] / 5879
cons_lom['per_1000']       = cons_lom['numero_dosi'] / 10060
cons_lig['per_1000']       = cons_lig['numero_dosi'] / 1551
cons_mar['per_1000']       = cons_mar['numero_dosi'] / 1525
cons_mol['per_1000']       = cons_mol['numero_dosi'] / 305.617
cons_pab['per_1000']       = cons_pab['numero_dosi'] / 520.891
cons_pat['per_1000']       = cons_pat['numero_dosi'] / 739.139
cons_pie['per_1000']       = cons_pie['numero_dosi'] / 4356
cons_pug['per_1000']       = cons_pug['numero_dosi'] / 4029
cons_sar['per_1000']       = cons_sar['numero_dosi'] / 1640
cons_sic['per_1000']       = cons_sic['numero_dosi'] / 5000
cons_tos['per_1000']       = cons_tos['numero_dosi'] / 3730
cons_umb['per_1000']       = cons_umb['numero_dosi'] / 882.015
cons_vda['per_1000']       = cons_vda['numero_dosi'] / 125.666


consemr = cons_emr.set_index('data_consegna')
consven = cons_ven.set_index('data_consegna')
consvda = cons_vda.set_index('data_consegna')
conslom = cons_lom.set_index('data_consegna')
conslaz = cons_laz.set_index('data_consegna')
conslig = cons_lig.set_index('data_consegna')
conssar = cons_sar.set_index('data_consegna')
conssic = cons_sic.set_index('data_consegna')
constos = cons_tos.set_index('data_consegna')
conspug = cons_pug.set_index('data_consegna')
consabr = cons_abr.set_index('data_consegna')
consbas = cons_bas.set_index('data_consegna')
conscal = cons_cal.set_index('data_consegna')
conscam = cons_cam.set_index('data_consegna')
consmar = cons_mar.set_index('data_consegna')
consmol = cons_mol.set_index('data_consegna')
consfvg = cons_fvg.set_index('data_consegna')
conspat = cons_pat.set_index('data_consegna')
conspab = cons_pab.set_index('data_consegna')
conspie = cons_pie.set_index('data_consegna')
consumb = cons_umb.set_index('data_consegna')

consmol.index = pd.DatetimeIndex(consmol.index)
consmol = consmol.reindex(idx)
consmol.index = consmol.index.strftime('%d/%m/%Y')

consemr.index = pd.DatetimeIndex(consemr.index)
consemr = consemr.reindex(idx)
consemr.index = consemr.index.strftime('%d/%m/%Y')

consven.index = pd.DatetimeIndex(consven.index)
consven = consven.reindex(idx)
consven.index = consven.index.strftime('%d/%m/%Y')

consvda.index = pd.DatetimeIndex(consvda.index)
consvda = consvda.reindex(idx)
consvda.index = consvda.index.strftime('%d/%m/%Y')

conspie.index = pd.DatetimeIndex(conspie.index)
conspie = conspie.reindex(idx)
conspie.index = conspie.index.strftime('%d/%m/%Y')

conspab.index = pd.DatetimeIndex(conspab.index)
conspab = conspab.reindex(idx)
conspab.index = conspab.index.strftime('%d/%m/%Y')

conspat.index = pd.DatetimeIndex(conspat.index)
conspat = conspat.reindex(idx)
conspat.index = conspat.index.strftime('%d/%m/%Y')

consfvg.index = pd.DatetimeIndex(consfvg.index)
consfvg = consfvg.reindex(idx)
consfvg.index = consfvg.index.strftime('%d/%m/%Y')

consmar.index = pd.DatetimeIndex(consmar.index)
consmar = consmar.reindex(idx)
consmar.index = consmar.index.strftime('%d/%m/%Y')

consabr.index = pd.DatetimeIndex(consabr.index)
consabr = consabr.reindex(idx)
consabr.index = consabr.index.strftime('%d/%m/%Y')

consbas.index = pd.DatetimeIndex(consbas.index)
consbas = consbas.reindex(idx)
consbas.index = consbas.index.strftime('%d/%m/%Y')

conscal.index = pd.DatetimeIndex(conscal.index)
conscal = conscal.reindex(idx)
conscal.index = conscal.index.strftime('%d/%m/%Y')

conscam.index = pd.DatetimeIndex(conscam.index)
conscam = conscam.reindex(idx)
conscam.index = conscam.index.strftime('%d/%m/%Y')

conslig.index = pd.DatetimeIndex(conslig.index)
conslig = conslig.reindex(idx)
conslig.index = conslig.index.strftime('%d/%m/%Y')

conslaz.index = pd.DatetimeIndex(conslaz.index)
conslaz = conslaz.reindex(idx)
conslaz.index = conslaz.index.strftime('%d/%m/%Y')

conslom.index = pd.DatetimeIndex(conslom.index)
conslom = conslom.reindex(idx)
conslom.index = conslom.index.strftime('%d/%m/%Y')

conssic.index = pd.DatetimeIndex(conssic.index)
conssic = conssic.reindex(idx)
conssic.index = conssic.index.strftime('%d/%m/%Y')

conssar.index = pd.DatetimeIndex(conssar.index)
conssar = conssar.reindex(idx)
conssar.index = conssar.index.strftime('%d/%m/%Y')

constos.index = pd.DatetimeIndex(constos.index)
constos = constos.reindex(idx)
constos.index = constos.index.strftime('%d/%m/%Y')

conspug.index = pd.DatetimeIndex(conspug.index)
conspug = conspug.reindex(idx)
conspug.index = conspug.index.strftime('%d/%m/%Y')

consumb.index = pd.DatetimeIndex(consumb.index)
consumb = consumb.reindex(idx)
consumb.index = consumb.index.strftime('%d/%m/%Y')

consumb
# Out:
# <ipython-input-120-68eee45013db>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cons_emr['per_1000']       = cons_emr['numero_dosi'] / 4459
# <ipython-input-120-68eee45013db>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cons_ven['per_1000']       = cons_ven['numero_dosi'] / 4906
# <ipython-input-120-68eee45013db>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
consemr['colors'] = 'C0'
consemr.loc[consemr.fornitore=='Moderna','colors'] = 'orange'

consven['colors'] = 'C0'
consven.loc[consven.fornitore=='Moderna','colors'] = 'orange'

consfvg['colors'] = 'C0'
consfvg.loc[consfvg.fornitore=='Moderna','colors'] = 'orange'

conspie['colors'] = 'C0'
conspie.loc[conspie.fornitore=='Moderna','colors'] = 'orange'

consvda['colors'] = 'C0'
consvda.loc[consvda.fornitore=='Moderna','colors'] = 'orange'

conslig['colors'] = 'C0'
conslig.loc[conslig.fornitore=='Moderna','colors'] = 'orange'

conspat['colors'] = 'C0'
conspat.loc[conspat.fornitore=='Moderna','colors'] = 'orange'

conspab['colors'] = 'C0'
conspab.loc[conspab.fornitore=='Moderna','colors'] = 'orange'

conslom['colors'] = 'C0'
conslom.loc[conslom.fornitore=='Moderna','colors'] = 'orange'

constos['colors'] = 'C0'
constos.loc[constos.fornitore=='Moderna','colors'] = 'orange'

consabr['colors'] = 'C0'
consabr.loc[consabr.fornitore=='Moderna','colors'] = 'orange'

consmar['colors'] = 'C0'
consmar.loc[consmar.fornitore=='Moderna','colors'] = 'orange'

consmol['colors'] = 'C0'
consmol.loc[consmol.fornitore=='Moderna','colors'] = 'orange'

consbas['colors'] = 'C0'
consbas.loc[consbas.fornitore=='Moderna','colors'] = 'orange'

conslaz['colors'] = 'C0'
conslaz.loc[conslaz.fornitore=='Moderna','colors'] = 'orange'

conssic['colors'] = 'C0'
conssic.loc[conssic.fornitore=='Moderna','colors'] = 'orange'

conssar['colors'] = 'C0'
conssar.loc[conssar.fornitore=='Moderna','colors'] = 'orange'

conspug['colors'] = 'C0'
conspug.loc[conspug.fornitore=='Moderna','colors'] = 'orange'

conscal['colors'] = 'C0'
conscal.loc[conscal.fornitore=='Moderna','colors'] = 'orange'

conscam['colors'] = 'C0'
conscam.loc[conscam.fornitore=='Moderna','colors'] = 'orange'

consumb['colors'] = 'C0'
consumb.loc[consumb.fornitore=='Moderna','colors'] = 'orange'

cons['colors'] = 'C0'
cons.loc[cons.fornitore=='Moderna','colors'] = 'orange'

# %%
fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})



plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
consabr.plot(ax=axes[0,0], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "ABR", color=consabr.colors)
consbas.plot(ax=axes[0,1], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "BAS", color=consbas.colors)
conscal.plot(ax=axes[0,2], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "CAL", color=conscal.colors)
conscam.plot(ax=axes[0,3], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "CAM", color=conscam.colors)
consemr.plot(ax=axes[0,4], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "EMR", color=consemr.colors)
consfvg.plot(ax=axes[0,5], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "FVG", color=consfvg.colors)
conslaz.plot(ax=axes[0,6], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "LAZ", color=conslaz.colors)
conslig.plot(ax=axes[1,0], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "LIG", color=conslig.colors)
conslom.plot(ax=axes[1,1], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "LOM", color=conslom.colors)
consmar.plot(ax=axes[1,2], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "MAR", color=consmar.colors)
consmol.plot(ax=axes[1,3], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "MOL", color=consmol.colors)
conspab.plot(ax=axes[1,4], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PAB", color=conspab.colors)
conspat.plot(ax=axes[1,5], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PAT", color=conspat.colors)
conspie.plot(ax=axes[1,6], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PIE", color=conspie.colors)
conspug.plot(ax=axes[2,0], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "PUG", color=conspug.colors)
conssar.plot(ax=axes[2,1], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "SAR", color=conssar.colors)
conssic.plot(ax=axes[2,2], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "SIC", color=conssic.colors)
constos.plot(ax=axes[2,3], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "TOS", color=constos.colors)
consumb.plot(ax=axes[2,4], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "UMB", color=consumb.colors)
consvda.plot(ax=axes[2,5], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "VDA", color=consvda.colors)
consven.plot(ax=axes[2,6], y='per_1000', kind = 'bar', legend = False, xlabel = '', title = "VEN", color=consven.colors)


plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))



axes[0,0].set_title('ABR', y=1.05, pad=0)
axes[0,1].set_title('BAS', y=1.05, pad=0)
axes[0,2].set_title('CAL', y=1.05, pad=0)
axes[0,3].set_title('CAM', y=1.05, pad=0)
axes[0,4].set_title('EMR', y=1.05, pad=0)
axes[0,5].set_title('FVG', y=1.05, pad=0)
axes[0,6].set_title('LAZ', y=1.05, pad=0)
axes[1,0].set_title('LIG', y=1.05, pad=0)
axes[1,1].set_title('LOM', y=1.05, pad=0)
axes[1,2].set_title('MAR', y=1.05, pad=0)
axes[1,3].set_title('MOL', y=1.05, pad=0)
axes[1,4].set_title('PAB', y=1.05, pad=0)
axes[1,5].set_title('PAT', y=1.05, pad=0)
axes[1,6].set_title('PIE', y=1.05, pad=0)
axes[2,0].set_title('PUG', y=1.05, pad=0)
axes[2,1].set_title('SAR', y=1.05, pad=0)
axes[2,2].set_title('SIC', y=1.05, pad=0)
axes[2,3].set_title('TOS', y=1.05, pad=0)
axes[2,4].set_title('UMB', y=1.05, pad=0)
axes[2,5].set_title('VDA', y=1.05, pad=0)
axes[2,6].set_title('VEN', y=1.05, pad=0)

fig.suptitle("Consegne per regione per 1000 abitanti", fontsize=14)
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Regioni_Cons_1000.png', dpi=300)

# %%
fig, axes = plt.subplots(nrows=3, ncols=7, dpi = 1000, gridspec_kw={'hspace': -0.5, 'wspace': 0.05})



somm1_abr.groupby(['fascia_anagrafica']).sum().plot(ax=axes[0,0], kind='pie', y='totale', legend=False, xlabel = '', title = "ABR", ylabel = '', textprops={'fontsize': 2})
somm1_bas.groupby(['fascia_anagrafica']).sum().plot(ax=axes[0,1], kind='pie', y='totale', legend=False, xlabel = '', title = "BAS", ylabel = '', textprops={'fontsize': 2})
somm1_cal.groupby(['fascia_anagrafica']).sum().plot(ax=axes[0,2], kind='pie', y='totale', legend=False, xlabel = '', title = "CAL", ylabel = '', textprops={'fontsize': 2})
somm1_cam.groupby(['fascia_anagrafica']).sum().plot(ax=axes[0,3], kind='pie', y='totale', legend=False, xlabel = '', title = "CAM", ylabel = '', textprops={'fontsize': 2})
somm1_emr.groupby(['fascia_anagrafica']).sum().plot(ax=axes[0,4], kind='pie', y='totale', legend=False, xlabel = '', title = "EMR", ylabel = '', textprops={'fontsize': 2})
somm1_fvg.groupby(['fascia_anagrafica']).sum().plot(ax=axes[0,5], kind='pie', y='totale', legend=False, xlabel = '', title = "FVG", ylabel = '', textprops={'fontsize': 2})
somm1_laz.groupby(['fascia_anagrafica']).sum().plot(ax=axes[0,6], kind='pie', y='totale', legend=False, xlabel = '', title = "LAZ", ylabel = '', textprops={'fontsize': 2})
somm1_lig.groupby(['fascia_anagrafica']).sum().plot(ax=axes[1,0], kind='pie', y='totale', legend=False, xlabel = '', title = "LIG", ylabel = '', textprops={'fontsize': 2})
somm1_lom.groupby(['fascia_anagrafica']).sum().plot(ax=axes[1,1], kind='pie', y='totale', legend=False, xlabel = '', title = "LOM", ylabel = '', textprops={'fontsize': 2})
somm1_mar.groupby(['fascia_anagrafica']).sum().plot(ax=axes[1,2], kind='pie', y='totale', legend=False, xlabel = '', title = "MAR", ylabel = '', textprops={'fontsize': 2})
somm1_mol.groupby(['fascia_anagrafica']).sum().plot(ax=axes[1,3], kind='pie', y='totale', legend=False, xlabel = '', title = "MOL", ylabel = '', textprops={'fontsize': 2})
somm1_pab.groupby(['fascia_anagrafica']).sum().plot(ax=axes[1,4], kind='pie', y='totale', legend=False, xlabel = '', title = "PAB", ylabel = '', textprops={'fontsize': 2})
somm1_pat.groupby(['fascia_anagrafica']).sum().plot(ax=axes[1,5], kind='pie', y='totale', legend=False, xlabel = '', title = "PAT", ylabel = '', textprops={'fontsize': 2})
somm1_pie.groupby(['fascia_anagrafica']).sum().plot(ax=axes[1,6], kind='pie', y='totale', legend=False, xlabel = '', title = "PIE", ylabel = '', textprops={'fontsize': 2})
somm1_pug.groupby(['fascia_anagrafica']).sum().plot(ax=axes[2,0], kind='pie', y='totale', legend=False, xlabel = '', title = "PUG", ylabel = '', textprops={'fontsize': 2})
somm1_sar.groupby(['fascia_anagrafica']).sum().plot(ax=axes[2,1], kind='pie', y='totale', legend=False, xlabel = '', title = "SAR", ylabel = '', textprops={'fontsize': 2})
somm1_sic.groupby(['fascia_anagrafica']).sum().plot(ax=axes[2,2], kind='pie', y='totale', legend=False, xlabel = '', title = "SIC", ylabel = '', textprops={'fontsize': 2})
somm1_tos.groupby(['fascia_anagrafica']).sum().plot(ax=axes[2,3], kind='pie', y='totale', legend=False, xlabel = '', title = "TOS", ylabel = '', textprops={'fontsize': 2})
somm1_umb.groupby(['fascia_anagrafica']).sum().plot(ax=axes[2,4], kind='pie', y='totale', legend=False, xlabel = '', title = "UMB", ylabel = '', textprops={'fontsize': 2})
somm1_vda.groupby(['fascia_anagrafica']).sum().plot(ax=axes[2,5], kind='pie', y='totale', legend=False, xlabel = '', title = "VDA", ylabel = '', textprops={'fontsize': 2})
somm1_ven.groupby(['fascia_anagrafica']).sum().plot(ax=axes[2,6], kind='pie', y='totale', legend=False, xlabel = '', title = "VEN", ylabel = '', textprops={'fontsize': 2})



axes[0,0].set_title('ABR', y=1.05, pad=0)
axes[0,1].set_title('BAS', y=1.05, pad=0)
axes[0,2].set_title('CAL', y=1.05, pad=0)
axes[0,3].set_title('CAM', y=1.05, pad=0)
axes[0,4].set_title('EMR', y=1.05, pad=0)
axes[0,5].set_title('FVG', y=1.05, pad=0)
axes[0,6].set_title('LAZ', y=1.05, pad=0)
axes[1,0].set_title('LIG', y=1.05, pad=0)
axes[1,1].set_title('LOM', y=1.05, pad=0)
axes[1,2].set_title('MAR', y=1.05, pad=0)
axes[1,3].set_title('MOL', y=1.05, pad=0)
axes[1,4].set_title('PAB', y=1.05, pad=0)
axes[1,5].set_title('PAT', y=1.05, pad=0)
axes[1,6].set_title('PIE', y=1.05, pad=0)
axes[2,0].set_title('PUG', y=1.05, pad=0)
axes[2,1].set_title('SAR', y=1.05, pad=0)
axes[2,2].set_title('SIC', y=1.05, pad=0)
axes[2,3].set_title('TOS', y=1.05, pad=0)
axes[2,4].set_title('UMB', y=1.05, pad=0)
axes[2,5].set_title('VDA', y=1.05, pad=0)
axes[2,6].set_title('VEN', y=1.05, pad=0)

plt.rcParams['font.size'] = '4' 

fig.suptitle("Divisione anagrafica per regione", fontsize=10, y=0.95)
plt.text(0.9, 0.2, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Torte_Regioni_Età.png', dpi=1000)

# %%
lig
# Out:
#            area  totale  sesso_maschile  sesso_femminile  \
# 27/12/2020  LIG   131.0            54.0             77.0
# 28/12/2020  LIG    75.0            26.0             49.0
# 29/12/2020  LIG   118.0            32.0             86.0
# 30/12/2020  LIG     9.0             3.0              6.0
# 31/12/2020  LIG   891.0           322.0            569.0
# 01/01/2021  LIG   144.0            55.0             89.0
# 02/01/2021  LIG   687.0           245.0            442.0
# 03/01/2021  LIG   686.0           218.0            468.0
# 04/01/2021  LIG  2300.0           776.0           1524.0
# 05/01/2021  LIG  2741.0           852.0           1889.0
# 06/01/2021  LIG  1627.0           599.0           1028.0
# 07/01/2021  LIG  2925.0          1011.0           1914.0
# 08/01/2021  LIG  2668.0           921.0           1747.0
# 09/01/2021  LIG  1301.0           461.0            840.0
# 10/01/2021  LIG   571.0           238.0            333.0
# ...

# %%
emr['avg_1000'] = emr['per_1000'].rolling(window=7, min_periods=1).mean()
abr['avg_1000'] = abr['per_1000'].rolling(window=7, min_periods=1).mean()
bas['avg_1000'] = bas['per_1000'].rolling(window=7, min_periods=1).mean()
cal['avg_1000'] = cal['per_1000'].rolling(window=7, min_periods=1).mean()
cam['avg_1000'] = cam['per_1000'].rolling(window=7, min_periods=1).mean()
fvg['avg_1000'] = fvg['per_1000'].rolling(window=7, min_periods=1).mean()
laz['avg_1000'] = laz['per_1000'].rolling(window=7, min_periods=1).mean()
lig['avg_1000'] = lig['per_1000'].rolling(window=7, min_periods=1).mean()
lom['avg_1000'] = lom['per_1000'].rolling(window=7, min_periods=1).mean()
mar['avg_1000'] = mar['per_1000'].rolling(window=7, min_periods=1).mean()
mol['avg_1000'] = mol['per_1000'].rolling(window=7, min_periods=1).mean()
pab['avg_1000'] = pab['per_1000'].rolling(window=7, min_periods=1).mean()
pat['avg_1000'] = pat['per_1000'].rolling(window=7, min_periods=1).mean()
pie['avg_1000'] = pie['per_1000'].rolling(window=7, min_periods=1).mean()
pug['avg_1000'] = pug['per_1000'].rolling(window=7, min_periods=1).mean()
sar['avg_1000'] = sar['per_1000'].rolling(window=7, min_periods=1).mean()
sic['avg_1000'] = sic['per_1000'].rolling(window=7, min_periods=1).mean()
tos['avg_1000'] = tos['per_1000'].rolling(window=7, min_periods=1).mean()
umb['avg_1000'] = umb['per_1000'].rolling(window=7, min_periods=1).mean()
vda['avg_1000'] = vda['per_1000'].rolling(window=7, min_periods=1).mean()
ven['avg_1000'] = ven['per_1000'].rolling(window=7, min_periods=1).mean()

emr['avg_prima_1000'] = emr['prima_1000'].rolling(window=7, min_periods=1).mean()
abr['avg_prima_1000'] = abr['prima_1000'].rolling(window=7, min_periods=1).mean()
bas['avg_prima_1000'] = bas['prima_1000'].rolling(window=7, min_periods=1).mean()
cal['avg_prima_1000'] = cal['prima_1000'].rolling(window=7, min_periods=1).mean()
cam['avg_prima_1000'] = cam['prima_1000'].rolling(window=7, min_periods=1).mean()
fvg['avg_prima_1000'] = fvg['prima_1000'].rolling(window=7, min_periods=1).mean()
laz['avg_prima_1000'] = laz['prima_1000'].rolling(window=7, min_periods=1).mean()
lig['avg_prima_1000'] = lig['prima_1000'].rolling(window=7, min_periods=1).mean()
lom['avg_prima_1000'] = lom['prima_1000'].rolling(window=7, min_periods=1).mean()
mar['avg_prima_1000'] = mar['prima_1000'].rolling(window=7, min_periods=1).mean()
mol['avg_prima_1000'] = mol['prima_1000'].rolling(window=7, min_periods=1).mean()
pab['avg_prima_1000'] = pab['prima_1000'].rolling(window=7, min_periods=1).mean()
pat['avg_prima_1000'] = pat['prima_1000'].rolling(window=7, min_periods=1).mean()
pie['avg_prima_1000'] = pie['prima_1000'].rolling(window=7, min_periods=1).mean()
pug['avg_prima_1000'] = pug['prima_1000'].rolling(window=7, min_periods=1).mean()
sar['avg_prima_1000'] = sar['prima_1000'].rolling(window=7, min_periods=1).mean()
sic['avg_prima_1000'] = sic['prima_1000'].rolling(window=7, min_periods=1).mean()
tos['avg_prima_1000'] = tos['prima_1000'].rolling(window=7, min_periods=1).mean()
umb['avg_prima_1000'] = umb['prima_1000'].rolling(window=7, min_periods=1).mean()
vda['avg_prima_1000'] = vda['prima_1000'].rolling(window=7, min_periods=1).mean()
ven['avg_prima_1000'] = ven['prima_1000'].rolling(window=7, min_periods=1).mean()

emr['avg_seconda_1000'] = emr['seconda_1000'].rolling(window=7, min_periods=1).mean()
abr['avg_seconda_1000'] = abr['seconda_1000'].rolling(window=7, min_periods=1).mean()
bas['avg_seconda_1000'] = bas['seconda_1000'].rolling(window=7, min_periods=1).mean()
cal['avg_seconda_1000'] = cal['seconda_1000'].rolling(window=7, min_periods=1).mean()
cam['avg_seconda_1000'] = cam['seconda_1000'].rolling(window=7, min_periods=1).mean()
fvg['avg_seconda_1000'] = fvg['seconda_1000'].rolling(window=7, min_periods=1).mean()
laz['avg_seconda_1000'] = laz['seconda_1000'].rolling(window=7, min_periods=1).mean()
lig['avg_seconda_1000'] = lig['seconda_1000'].rolling(window=7, min_periods=1).mean()
lom['avg_seconda_1000'] = lom['seconda_1000'].rolling(window=7, min_periods=1).mean()
mar['avg_seconda_1000'] = mar['seconda_1000'].rolling(window=7, min_periods=1).mean()
mol['avg_seconda_1000'] = mol['seconda_1000'].rolling(window=7, min_periods=1).mean()
pab['avg_seconda_1000'] = pab['seconda_1000'].rolling(window=7, min_periods=1).mean()
pat['avg_seconda_1000'] = pat['seconda_1000'].rolling(window=7, min_periods=1).mean()
pie['avg_seconda_1000'] = pie['seconda_1000'].rolling(window=7, min_periods=1).mean()
pug['avg_seconda_1000'] = pug['seconda_1000'].rolling(window=7, min_periods=1).mean()
sar['avg_seconda_1000'] = sar['seconda_1000'].rolling(window=7, min_periods=1).mean()
sic['avg_seconda_1000'] = sic['seconda_1000'].rolling(window=7, min_periods=1).mean()
tos['avg_seconda_1000'] = tos['seconda_1000'].rolling(window=7, min_periods=1).mean()
umb['avg_seconda_1000'] = umb['seconda_1000'].rolling(window=7, min_periods=1).mean()
vda['avg_seconda_1000'] = vda['seconda_1000'].rolling(window=7, min_periods=1).mean()
ven['avg_seconda_1000'] = ven['seconda_1000'].rolling(window=7, min_periods=1).mean()

fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})


abr.plot(ax=axes[0,0], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "ABR"    )
abr.plot(ax=axes[0,0], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
bas.plot(ax=axes[0,1], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "BAS"    )
bas.plot(ax=axes[0,1], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
cal.plot(ax=axes[0,2], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "CAL"    )
cal.plot(ax=axes[0,2], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
cam.plot(ax=axes[0,3], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "CAM"    )
cam.plot(ax=axes[0,3], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
emr.plot(ax=axes[0,4], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "EMR"    )
emr.plot(ax=axes[0,4], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
fvg.plot(ax=axes[0,5], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "FVG"    )
fvg.plot(ax=axes[0,5], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
laz.plot(ax=axes[0,6], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "LAZ"    )
laz.plot(ax=axes[0,6], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
lig.plot(ax=axes[1,0], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "LIG"    )
lig.plot(ax=axes[1,0], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
lom.plot(ax=axes[1,1], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "LOM"    )
lom.plot(ax=axes[1,1], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
mar.plot(ax=axes[1,2], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "MAR"    )
mar.plot(ax=axes[1,2], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
mol.plot(ax=axes[1,3], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "MOL"    )
mol.plot(ax=axes[1,3], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pab.plot(ax=axes[1,4], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "PAB"    )
pab.plot(ax=axes[1,4], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pat.plot(ax=axes[1,5], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "PAT"    )
pat.plot(ax=axes[1,5], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pie.plot(ax=axes[1,6], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "PIE"    )
pie.plot(ax=axes[1,6], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pug.plot(ax=axes[2,0], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "PUG"    )
pug.plot(ax=axes[2,0], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
sar.plot(ax=axes[2,1], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "SAR"    )
sar.plot(ax=axes[2,1], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
sic.plot(ax=axes[2,2], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "SIC"    )
sic.plot(ax=axes[2,2], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
tos.plot(ax=axes[2,3], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "TOS"    )
tos.plot(ax=axes[2,3], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
umb.plot(ax=axes[2,4], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "UMB"    )
umb.plot(ax=axes[2,4], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
vda.plot(ax=axes[2,5], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "VDA"    )
vda.plot(ax=axes[2,5], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
ven.plot(ax=axes[2,6], y='per_1000', kind = 'bar',  legend = False, xlabel = '', title = "VEN"    )
ven.plot(ax=axes[2,6], y='avg_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )



axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.setp(axes[2,0].get_xticklabels(), rotation=90)
plt.setp(axes[2,1].get_xticklabels(), rotation=90)
plt.setp(axes[2,2].get_xticklabels(), rotation=90)
plt.setp(axes[2,3].get_xticklabels(), rotation=90)
plt.setp(axes[2,4].get_xticklabels(), rotation=90)
plt.setp(axes[2,5].get_xticklabels(), rotation=90)
plt.setp(axes[2,6].get_xticklabels(), rotation=90)



axes[0,0].set_title('ABR', y=1.05, pad=0)
axes[0,1].set_title('BAS', y=1.05, pad=0)
axes[0,2].set_title('CAL', y=1.05, pad=0)
axes[0,3].set_title('CAM', y=1.05, pad=0)
axes[0,4].set_title('EMR', y=1.05, pad=0)
axes[0,5].set_title('FVG', y=1.05, pad=0)
axes[0,6].set_title('LAZ', y=1.05, pad=0)
axes[1,0].set_title('LIG', y=1.05, pad=0)
axes[1,1].set_title('LOM', y=1.05, pad=0)
axes[1,2].set_title('MAR', y=1.05, pad=0)
axes[1,3].set_title('MOL', y=1.05, pad=0)
axes[1,4].set_title('PAB', y=1.05, pad=0)
axes[1,5].set_title('PAT', y=1.05, pad=0)
axes[1,6].set_title('PIE', y=1.05, pad=0)
axes[2,0].set_title('PUG', y=1.05, pad=0)
axes[2,1].set_title('SAR', y=1.05, pad=0)
axes[2,2].set_title('SIC', y=1.05, pad=0)
axes[2,3].set_title('TOS', y=1.05, pad=0)
axes[2,4].set_title('UMB', y=1.05, pad=0)
axes[2,5].set_title('VDA', y=1.05, pad=0)
axes[2,6].set_title('VEN', y=1.05, pad=0)

fig.suptitle("Vaccinati per regione, per 1000 abitanti", fontsize=11)
plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Regioni_Giorn_1000.png', dpi=300)
plt.show()

# %%
consemr['cumulativa'] = consemr['per_1000'].cumsum()
consven['cumulativa'] = consven['per_1000'].cumsum()
consabr['cumulativa'] = consabr['per_1000'].cumsum()
consbas['cumulativa'] = consbas['per_1000'].cumsum()
conscal['cumulativa'] = conscal['per_1000'].cumsum()
conscam['cumulativa'] = conscam['per_1000'].cumsum()
consfvg['cumulativa'] = consfvg['per_1000'].cumsum()
conslaz['cumulativa'] = conslaz['per_1000'].cumsum()
conslom['cumulativa'] = conslom['per_1000'].cumsum()
consmar['cumulativa'] = consmar['per_1000'].cumsum()
consmol['cumulativa'] = consmol['per_1000'].cumsum()
conspab['cumulativa'] = conspab['per_1000'].cumsum()
conspat['cumulativa'] = conspat['per_1000'].cumsum()
conspie['cumulativa'] = conspie['per_1000'].cumsum()
conspug['cumulativa'] = conspug['per_1000'].cumsum()
conssar['cumulativa'] = conssar['per_1000'].cumsum()
conssic['cumulativa'] = conssic['per_1000'].cumsum()
constos['cumulativa'] = constos['per_1000'].cumsum()
consumb['cumulativa'] = consumb['per_1000'].cumsum()
consvda['cumulativa'] = consvda['per_1000'].cumsum()
conslig['cumulativa'] = conslig['per_1000'].cumsum()

consemr.cumulativa.fillna(method='ffill', inplace = True )
consven.cumulativa.fillna(method='ffill', inplace = True )
consabr.cumulativa.fillna(method='ffill', inplace = True )
consbas.cumulativa.fillna(method='ffill', inplace = True )
conscal.cumulativa.fillna(method='ffill', inplace = True )
conscam.cumulativa.fillna(method='ffill', inplace = True )
conslaz.cumulativa.fillna(method='ffill', inplace = True )
consfvg.cumulativa.fillna(method='ffill', inplace = True )
conslom.cumulativa.fillna(method='ffill', inplace = True )
consmar.cumulativa.fillna(method='ffill', inplace = True )
consmol.cumulativa.fillna(method='ffill', inplace = True )
conspab.cumulativa.fillna(method='ffill', inplace = True )
conspat.cumulativa.fillna(method='ffill', inplace = True )
conspie.cumulativa.fillna(method='ffill', inplace = True )
conspug.cumulativa.fillna(method='ffill', inplace = True )
conssar.cumulativa.fillna(method='ffill', inplace = True )
conssic.cumulativa.fillna(method='ffill', inplace = True )
constos.cumulativa.fillna(method='ffill', inplace = True )
consumb.cumulativa.fillna(method='ffill', inplace = True )
consvda.cumulativa.fillna(method='ffill', inplace = True )
conslig.cumulativa.fillna(method='ffill', inplace = True )



fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})

consabr.plot(ax=axes[0,0], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "ABR")
consbas.plot(ax=axes[0,1], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "BAS")
conscal.plot(ax=axes[0,2], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "CAL")
conscam.plot(ax=axes[0,3], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "CAM")
consemr.plot(ax=axes[0,4], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "EMR")
consfvg.plot(ax=axes[0,5], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "FVG")
conslaz.plot(ax=axes[0,6], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "LAZ")
conslig.plot(ax=axes[1,0], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "LIG")
conslom.plot(ax=axes[1,1], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "LOM")
consmar.plot(ax=axes[1,2], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "MAR")
consmol.plot(ax=axes[1,3], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "MOL")
conspab.plot(ax=axes[1,4], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "PAB")
conspat.plot(ax=axes[1,5], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "PAT")
conspie.plot(ax=axes[1,6], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "PIE")
conspug.plot(ax=axes[2,0], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "PUG")
conssar.plot(ax=axes[2,1], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "SAR")
conssic.plot(ax=axes[2,2], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "SIC")
constos.plot(ax=axes[2,3], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "TOS")
consumb.plot(ax=axes[2,4], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "UMB")
consvda.plot(ax=axes[2,5], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "VDA")
consven.plot(ax=axes[2,6], y='cumulativa', kind = 'bar', legend = False, xlabel = '', title = "VEN")



axes[0,0].set_title('ABR', y=1.05, pad=0)
axes[0,1].set_title('BAS', y=1.05, pad=0)
axes[0,2].set_title('CAL', y=1.05, pad=0)
axes[0,3].set_title('CAM', y=1.05, pad=0)
axes[0,4].set_title('EMR', y=1.05, pad=0)
axes[0,5].set_title('FVG', y=1.05, pad=0)
axes[0,6].set_title('LAZ', y=1.05, pad=0)
axes[1,0].set_title('LIG', y=1.05, pad=0)
axes[1,1].set_title('LOM', y=1.05, pad=0)
axes[1,2].set_title('MAR', y=1.05, pad=0)
axes[1,3].set_title('MOL', y=1.05, pad=0)
axes[1,4].set_title('PAB', y=1.05, pad=0)
axes[1,5].set_title('PAT', y=1.05, pad=0)
axes[1,6].set_title('PIE', y=1.05, pad=0)
axes[2,0].set_title('PUG', y=1.05, pad=0)
axes[2,1].set_title('SAR', y=1.05, pad=0)
axes[2,2].set_title('SIC', y=1.05, pad=0)
axes[2,3].set_title('TOS', y=1.05, pad=0)
axes[2,4].set_title('UMB', y=1.05, pad=0)
axes[2,5].set_title('VDA', y=1.05, pad=0)
axes[2,6].set_title('VEN', y=1.05, pad=0)

axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))


plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')
fig.suptitle("Dosi disponibili per regione per 1000 abitanti", fontsize=10)

plt.savefig('Regioni_Cons_Tot.png', dpi=300)

# %%
cols = consemr.columns.difference(emr.columns)
consemr[cols]

cols = consven.columns.difference(ven.columns)
consven[cols]

cols = consvda.columns.difference(vda.columns)
consvda[cols]

cols = consumb.columns.difference(umb.columns)
consumb[cols]

cols = constos.columns.difference(tos.columns)
constos[cols]

cols = conssar.columns.difference(sar.columns)
conssar[cols]

cols = conssic.columns.difference(sic.columns)
conssic[cols]

cols = conspug.columns.difference(pug.columns)
conspug[cols]

cols = conspie.columns.difference(pie.columns)
conspie[cols]

cols = conspat.columns.difference(pat.columns)
conspat[cols]

cols = conspab.columns.difference(pab.columns)
conspab[cols]

cols = consmol.columns.difference(mol.columns)
consmol[cols]

cols = consmar.columns.difference(mar.columns)
consmar[cols]

cols = conslom.columns.difference(lom.columns)
conslom[cols]

cols = conslig.columns.difference(lig.columns)
conslig[cols]

cols = conslaz.columns.difference(laz.columns)
conslaz[cols]

cols = consfvg.columns.difference(fvg.columns)
consfvg[cols]

cols = conscam.columns.difference(cam.columns)
conscam[cols]

cols = conscal.columns.difference(cal.columns)
conscal[cols]

cols = consbas.columns.difference(bas.columns)
consbas[cols]

cols = consabr.columns.difference(abr.columns)
consabr[cols]


emr = pd.concat([emr, consemr[cols]], axis=1)
emr['cumulativa_dosi'] = consven['numero_dosi'].cumsum()
emr.cumulativa_dosi.fillna(method='ffill', inplace = True )
emr['dosi_rimaste'] = emr['cumulativa_dosi'] - emr['cumulativa']

ven = pd.concat([ven, consven[cols]], axis=1)
ven['cumulativa_dosi'] = consven['numero_dosi'].cumsum()
ven.cumulativa_dosi.fillna(method='ffill', inplace = True )
ven['dosi_rimaste'] = ven['cumulativa_dosi'] - ven['cumulativa']


abr = pd.concat([abr, consabr[cols]], axis=1)
abr['cumulativa_dosi'] = consabr['numero_dosi'].cumsum()
abr.cumulativa_dosi.fillna(method='ffill', inplace = True )
abr['dosi_rimaste'] = abr['cumulativa_dosi'] - abr['cumulativa']

bas = pd.concat([bas, consbas[cols]], axis=1)
bas['cumulativa_dosi'] = consbas['numero_dosi'].cumsum()
bas.cumulativa_dosi.fillna(method='ffill', inplace = True )
bas['dosi_rimaste'] = bas['cumulativa_dosi'] - bas['cumulativa']

cal = pd.concat([cal, conscal[cols]], axis=1)
cal['cumulativa_dosi'] = conscal['numero_dosi'].cumsum()
cal.cumulativa_dosi.fillna(method='ffill', inplace = True )
cal['dosi_rimaste'] = cal['cumulativa_dosi'] - cal['cumulativa']

cam = pd.concat([cam, conscam[cols]], axis=1)
cam['cumulativa_dosi'] = conscam['numero_dosi'].cumsum()
cam.cumulativa_dosi.fillna(method='ffill', inplace = True )
cam['dosi_rimaste'] = cam['cumulativa_dosi'] - cam['cumulativa']

fvg = pd.concat([fvg, consfvg[cols]], axis=1)
fvg['cumulativa_dosi'] = consfvg['numero_dosi'].cumsum()
fvg.cumulativa_dosi.fillna(method='ffill', inplace = True )
fvg['dosi_rimaste'] = fvg['cumulativa_dosi'] - fvg['cumulativa']

laz = pd.concat([laz, conslaz[cols]], axis=1)
laz['cumulativa_dosi'] = conslaz['numero_dosi'].cumsum()
laz.cumulativa_dosi.fillna(method='ffill', inplace = True )
laz['dosi_rimaste'] = laz['cumulativa_dosi'] - laz['cumulativa']


lig = pd.concat([lig, conslig[cols]], axis=1)
lig['cumulativa_dosi'] = conslig['numero_dosi'].cumsum()
lig.cumulativa_dosi.fillna(method='ffill', inplace = True )
lig['dosi_rimaste'] = lig['cumulativa_dosi'] - lig['cumulativa']

lom = pd.concat([lom, conslom[cols]], axis=1)
lom['cumulativa_dosi'] = conslom['numero_dosi'].cumsum()
lom.cumulativa_dosi.fillna(method='ffill', inplace = True )
lom['dosi_rimaste'] = lom['cumulativa_dosi'] - lom['cumulativa']

mar = pd.concat([mar, consmar[cols]], axis=1)
mar['cumulativa_dosi'] = consmar['numero_dosi'].cumsum()
mar.cumulativa_dosi.fillna(method='ffill', inplace = True )
mar['dosi_rimaste'] = mar['cumulativa_dosi'] - mar['cumulativa']

mol = pd.concat([mol, consmol[cols]], axis=1)
mol['cumulativa_dosi'] = consmol['numero_dosi'].cumsum()
mol.cumulativa_dosi.fillna(method='ffill', inplace = True )
mol['dosi_rimaste'] = mol['cumulativa_dosi'] - mol['cumulativa']

pab = pd.concat([pab, conspab[cols]], axis=1)
pab['cumulativa_dosi'] = conspab['numero_dosi'].cumsum()
pab.cumulativa_dosi.fillna(method='ffill', inplace = True )
pab['dosi_rimaste'] = pab['cumulativa_dosi'] - pab['cumulativa']

pat = pd.concat([pat, conspat[cols]], axis=1)
pat['cumulativa_dosi'] = conspat['numero_dosi'].cumsum()
pat.cumulativa_dosi.fillna(method='ffill', inplace = True )
pat['dosi_rimaste'] = pat['cumulativa_dosi'] - pat['cumulativa']

pie = pd.concat([pie, conspie[cols]], axis=1)
pie['cumulativa_dosi'] = conspie['numero_dosi'].cumsum()
pie.cumulativa_dosi.fillna(method='ffill', inplace = True )
pie['dosi_rimaste'] = pie['cumulativa_dosi'] - pie['cumulativa']

pug = pd.concat([pug, conspug[cols]], axis=1)
pug['cumulativa_dosi'] = conspug['numero_dosi'].cumsum()
pug.cumulativa_dosi.fillna(method='ffill', inplace = True )
pug['dosi_rimaste'] = pug['cumulativa_dosi'] - pug['cumulativa']

sar = pd.concat([sar, conssar[cols]], axis=1)
sar['cumulativa_dosi'] = conssar['numero_dosi'].cumsum()
sar.cumulativa_dosi.fillna(method='ffill', inplace = True )
sar['dosi_rimaste'] = sar['cumulativa_dosi'] - sar['cumulativa']

sic = pd.concat([sic, conssic[cols]], axis=1)
sic['cumulativa_dosi'] = conssic['numero_dosi'].cumsum()
sic.cumulativa_dosi.fillna(method='ffill', inplace = True )
sic['dosi_rimaste'] = sic['cumulativa_dosi'] - sic['cumulativa']

tos = pd.concat([tos, constos[cols]], axis=1)
tos['cumulativa_dosi'] = constos['numero_dosi'].cumsum()
tos.cumulativa_dosi.fillna(method='ffill', inplace = True )
tos['dosi_rimaste'] = tos['cumulativa_dosi'] - tos['cumulativa']

umb = pd.concat([umb, consumb[cols]], axis=1)
umb['cumulativa_dosi'] = consumb['numero_dosi'].cumsum()
umb.cumulativa_dosi.fillna(method='ffill', inplace = True )
umb['dosi_rimaste'] = umb['cumulativa_dosi'] - umb['cumulativa']

vda = pd.concat([vda, consvda[cols]], axis=1)
vda['cumulativa_dosi'] = consvda['numero_dosi'].cumsum()
vda.cumulativa_dosi.fillna(method='ffill', inplace = True )
vda['dosi_rimaste'] = vda['cumulativa_dosi'] - vda['cumulativa']


emr.dosi_rimaste.fillna(method='ffill', inplace = True)
vda.dosi_rimaste.fillna(method='ffill', inplace = True)
umb.dosi_rimaste.fillna(method='ffill', inplace = True)
ven.dosi_rimaste.fillna(method='ffill', inplace = True)
sic.dosi_rimaste.fillna(method='ffill', inplace = True)
tos.dosi_rimaste.fillna(method='ffill', inplace = True)
sar.dosi_rimaste.fillna(method='ffill', inplace = True)
sic.dosi_rimaste.fillna(method='ffill', inplace = True)
pug.dosi_rimaste.fillna(method='ffill', inplace = True)
mar.dosi_rimaste.fillna(method='ffill', inplace = True)
mol.dosi_rimaste.fillna(method='ffill', inplace = True)
lom.dosi_rimaste.fillna(method='ffill', inplace = True)
laz.dosi_rimaste.fillna(method='ffill', inplace = True)
lig.dosi_rimaste.fillna(method='ffill', inplace = True)
fvg.dosi_rimaste.fillna(method='ffill', inplace = True)
cam.dosi_rimaste.fillna(method='ffill', inplace = True)
cal.dosi_rimaste.fillna(method='ffill', inplace = True)
pab.dosi_rimaste.fillna(method='ffill', inplace = True)
pat.dosi_rimaste.fillna(method='ffill', inplace = True)
pie.dosi_rimaste.fillna(method='ffill', inplace = True)

# %%
emr['cons_1000']            = emr['numero_dosi'] / 4459
ven['cons_1000']            = ven['numero_dosi'] / 4906
abr['cons_1000']            = abr['numero_dosi'] / 1312
bas['cons_1000']            = bas['numero_dosi'] / 562.869
cal['cons_1000']            = cal['numero_dosi'] / 1947
cam['cons_1000']            = cam['numero_dosi'] / 5802
fvg['cons_1000']            = fvg['numero_dosi'] / 1215
laz['cons_1000']            = laz['numero_dosi'] / 5879
lom['cons_1000']            = lom['numero_dosi'] / 10060
lig['cons_1000']            = lig['numero_dosi'] / 1551
mar['cons_1000']            = mar['numero_dosi'] / 1525
mol['cons_1000']            = mol['numero_dosi'] / 305.617
pab['cons_1000']            = pab['numero_dosi'] / 520.891
pat['cons_1000']            = pat['numero_dosi'] / 739.139
pie['cons_1000']            = pie['numero_dosi'] / 4356
pug['cons_1000']            = pug['numero_dosi'] / 4029
sar['cons_1000']            = sar['numero_dosi'] / 1640
sic['cons_1000']            = sic['numero_dosi'] / 5000
tos['cons_1000']            = tos['numero_dosi'] / 3730
umb['cons_1000']            = umb['numero_dosi'] / 882.015
vda['cons_1000']            = vda['numero_dosi'] / 125.666

emr['cumulativa_dosi_1000'] = emr['cumulativa_dosi'] / 4459
ven['cumulativa_dosi_1000'] = ven['cumulativa_dosi'] / 4906
abr['cumulativa_dosi_1000'] = abr['cumulativa_dosi'] / 1312
bas['cumulativa_dosi_1000'] = bas['cumulativa_dosi'] / 562.869
cal['cumulativa_dosi_1000'] = cal['cumulativa_dosi'] / 1947
cam['cumulativa_dosi_1000'] = cam['cumulativa_dosi'] / 5802
fvg['cumulativa_dosi_1000'] = fvg['cumulativa_dosi'] / 1215
laz['cumulativa_dosi_1000'] = laz['cumulativa_dosi'] / 5879
lom['cumulativa_dosi_1000'] = lom['cumulativa_dosi'] / 10060
lig['cumulativa_dosi_1000'] = lig['cumulativa_dosi'] / 1551
mar['cumulativa_dosi_1000'] = mar['cumulativa_dosi'] / 1525
mol['cumulativa_dosi_1000'] = mol['cumulativa_dosi'] / 305.617
pab['cumulativa_dosi_1000'] = pab['cumulativa_dosi'] / 520.891
pat['cumulativa_dosi_1000'] = pat['cumulativa_dosi'] / 739.139
pie['cumulativa_dosi_1000'] = pie['cumulativa_dosi'] / 4356
pug['cumulativa_dosi_1000'] = pug['cumulativa_dosi'] / 4029
sar['cumulativa_dosi_1000'] = sar['cumulativa_dosi'] / 1640
sic['cumulativa_dosi_1000'] = sic['cumulativa_dosi'] / 5000
tos['cumulativa_dosi_1000'] = tos['cumulativa_dosi'] / 3730
umb['cumulativa_dosi_1000'] = umb['cumulativa_dosi'] / 882.015
vda['cumulativa_dosi_1000'] = vda['cumulativa_dosi'] / 125.666

emr['dosi_rimaste_1000']    = emr['dosi_rimaste'] / 4459
ven['dosi_rimaste_1000']    = ven['dosi_rimaste'] / 4906
abr['dosi_rimaste_1000']    = abr['dosi_rimaste'] / 1312
cal['dosi_rimaste_1000']    = cal['dosi_rimaste'] / 1947
cam['dosi_rimaste_1000']    = cam['dosi_rimaste'] / 5802
fvg['dosi_rimaste_1000']    = fvg['dosi_rimaste'] / 1215
laz['dosi_rimaste_1000']    = laz['dosi_rimaste'] / 5879
lom['dosi_rimaste_1000']    = lom['dosi_rimaste'] / 10060
lig['dosi_rimaste_1000']    = lig['dosi_rimaste'] / 1551
mar['dosi_rimaste_1000']    = mar['dosi_rimaste'] / 1525
pie['dosi_rimaste_1000']    = pie['dosi_rimaste'] / 4356
pug['dosi_rimaste_1000']    = pug['dosi_rimaste'] / 4029
sar['dosi_rimaste_1000']    = sar['dosi_rimaste'] / 1640
sic['dosi_rimaste_1000']    = sic['dosi_rimaste'] / 5000
tos['dosi_rimaste_1000']    = tos['dosi_rimaste'] / 3730
bas['dosi_rimaste_1000']    = bas['dosi_rimaste'] / 562.869
mol['dosi_rimaste_1000']    = mol['dosi_rimaste'] / 305.617
pab['dosi_rimaste_1000']    = pab['dosi_rimaste'] / 520.891
pat['dosi_rimaste_1000']    = pat['dosi_rimaste'] / 739.139
umb['dosi_rimaste_1000']    = umb['dosi_rimaste'] / 882.015
vda['dosi_rimaste_1000']    = vda['dosi_rimaste'] / 125.666

#emr.to_csv('emr.csv')
cons
# Out:
#     area        fornitore  numero_dosi data_consegna  colors
# 0    ABR  Pfizer/BioNTech          135    2020-12-27      C0
# 1    ABR  Pfizer/BioNTech         7800    2020-12-30      C0
# 2    ABR  Pfizer/BioNTech         3900    2021-01-05      C0
# 3    ABR  Pfizer/BioNTech         3900    2021-01-07      C0
# 4    ABR  Pfizer/BioNTech         3900    2021-01-11      C0
# ..   ...              ...          ...           ...     ...
# 163  VEN  Pfizer/BioNTech        34125    2021-01-07      C0
# 164  VEN  Pfizer/BioNTech        39000    2021-01-12      C0
# 165  VEN          Moderna         7800    2021-01-13  orange
# 166  VEN  Pfizer/BioNTech         7020    2021-01-20      C0
# 167  VEN  Pfizer/BioNTech        15210    2021-01-21      C0
#
# [168 rows x 5 columns]

# %%
fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})

abr.plot(ax=axes[0,0], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "ABR")
bas.plot(ax=axes[0,1], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "BAS")
cal.plot(ax=axes[0,2], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "CAL")
cam.plot(ax=axes[0,3], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "CAM")
emr.plot(ax=axes[0,4], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "EMR")
fvg.plot(ax=axes[0,5], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "FVG")
laz.plot(ax=axes[0,6], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "LAZ")
lig.plot(ax=axes[1,0], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "LIG")
lom.plot(ax=axes[1,1], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "LOM")
mar.plot(ax=axes[1,2], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "MAR")
mol.plot(ax=axes[1,3], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "MOL")
pab.plot(ax=axes[1,4], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "PAB")
pat.plot(ax=axes[1,5], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "PAT")
pie.plot(ax=axes[1,6], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "PIE")
pug.plot(ax=axes[2,0], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "PUG")
sar.plot(ax=axes[2,1], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "SAR")
sic.plot(ax=axes[2,2], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "SIC")
tos.plot(ax=axes[2,3], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "TOS")
umb.plot(ax=axes[2,4], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "UMB")
vda.plot(ax=axes[2,5], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "VDA")
ven.plot(ax=axes[2,6], y='dosi_rimaste_1000', kind = 'bar', legend = False, xlabel = '', title = "VEN")



axes[0,0].set_title('ABR', y=1.05, pad=0)
axes[0,1].set_title('BAS', y=1.05, pad=0)
axes[0,2].set_title('CAL', y=1.05, pad=0)
axes[0,3].set_title('CAM', y=1.05, pad=0)
axes[0,4].set_title('EMR', y=1.05, pad=0)
axes[0,5].set_title('FVG', y=1.05, pad=0)
axes[0,6].set_title('LAZ', y=1.05, pad=0)
axes[1,0].set_title('LIG', y=1.05, pad=0)
axes[1,1].set_title('LOM', y=1.05, pad=0)
axes[1,2].set_title('MAR', y=1.05, pad=0)
axes[1,3].set_title('MOL', y=1.05, pad=0)
axes[1,4].set_title('PAB', y=1.05, pad=0)
axes[1,5].set_title('PAT', y=1.05, pad=0)
axes[1,6].set_title('PIE', y=1.05, pad=0)
axes[2,0].set_title('PUG', y=1.05, pad=0)
axes[2,1].set_title('SAR', y=1.05, pad=0)
axes[2,2].set_title('SIC', y=1.05, pad=0)
axes[2,3].set_title('TOS', y=1.05, pad=0)
axes[2,4].set_title('UMB', y=1.05, pad=0)
axes[2,5].set_title('VDA', y=1.05, pad=0)
axes[2,6].set_title('VEN', y=1.05, pad=0)

axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))


plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
fig.suptitle("Dosi rimaste per regione per 1000 abitanti", fontsize=10)
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Regioni_Cons_Rimaste.png', dpi=300)

# %%
import sys
import geopandas as gpd
import matplotlib.colors as mcolors
import matplotlib.cm as cm

italy = gpd.read_file('italy-with-regions//reg2011_g.shp')
vaccini = pd.read_csv('../covid19-opendata-vaccini/dati/vaccini-summary-latest.csv')

vaccini1 = vaccini.set_index('area')
sum_ = vaccini1.loc[['PAT', 'PAB']].sum().to_frame().transpose()
sum_ = sum_.rename(index={0: 'TRE'})

vaccini1.drop(['PAT', 'PAB'],inplace=True)
vaccini1 = vaccini1.append(sum_)
vaccini1 = vaccini1.sort_index()

italy.sort_values(by = 'NOME_REG', inplace = True)
italy.reset_index(drop=True,       inplace = True)
italy.index = vaccini1.index

italy = italy.merge(vaccini1,left_index=True, right_index=True, how='right')
italy['percentuale_somministrazione'] = italy['dosi_somministrate'] / italy['dosi_consegnate'] * 100


fig, ax = plt.subplots(1, figsize=(15, 15))

col = 'percentuale_somministrazione'

ax.set_title('Percentuale somministrazioni per regione', 
             fontdict={'fontsize':'25', 'fontweight':'3'}, 
             color='Orange', 
             fontfamily='monospace')


normalize = mcolors.Normalize(vmin=italy['percentuale_somministrazione'].min(), vmax=italy['percentuale_somministrazione'].max())
#colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap="Blues")
scalarmappaple.set_array(italy['percentuale_somministrazione'])

italy.plot(ax=ax,
           column=col,
           cmap="Blues",
#           cmap=colormap,
#           label='ciao',
#           legend=True,
#           categorical=False
#           alpha = 1
          )

plt.axis('off')
cbar = plt.colorbar(scalarmappaple, shrink=0.5)
cbar.ax.tick_params(labelsize=11)
ax.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=ax.transAxes,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')


plt.savefig('Mappa_Perc.png', dpi=300)

# %%
vaccini
# Out:
#    area  dosi_somministrate  dosi_consegnate  percentuale_somministrazione  \
# 0   ABR               19160            35170                          54.5
# 1   BAS               11240            17265                          65.1
# 2   CAL               20553            48640                          42.3
# 3   CAM              113870           147955                          77.0
# 4   EMR              127416           165935                          76.8
# 5   FVG               35601            44335                          80.3
# 6   LAZ              135902           178690                          76.1
# 7   LIG               37140            65840                          56.4
# 8   LOM              218995           305820                          71.6
# 9   MAR               28531            39530                          72.2
# 10  MOL                6715            12335                          54.4
# ...

# %%
italy = gpd.read_file('italy-with-regions//reg2011_g.shp')

cum1 = cum.set_index('area')
sum_ = cum1.reindex(['PAT', 'PAB']).sum().to_frame().transpose()
sum_ = sum_.rename(index={0: 'TRE'})

cum1.drop(['PAT', 'PAB'],inplace=True)
cum1 = cum1.append(sum_)
cum1 = cum1.sort_index()

italy.sort_values(by = 'NOME_REG', inplace = True)
italy.reset_index(drop=True,       inplace = True)
italy.index = cum1.index

italy = italy.merge(cum1,left_index=True, right_index=True, how='right')

italy['cumulativa_1000']['TRE'] = italy['cumulativa']['TRE'] / 1072

fig, ax = plt.subplots(1, figsize=(15, 15))

col = 'cumulativa_1000'

ax.set_title('Dosi somministrate per regione per 1000 abitanti', 
             fontdict={'fontsize':'25', 'fontweight':'3'}, 
             color='Orange', 
             fontfamily='monospace')


normalize = mcolors.Normalize(vmin=italy['cumulativa_1000'].min(), vmax=italy['cumulativa_1000'].max())
#colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap="Blues")
scalarmappaple.set_array(italy['cumulativa_1000'])

italy.plot(ax=ax,
           column=col,
           cmap="Blues",
#           cmap=colormap,
#           label='ciao',
#           legend=True,
#           categorical=False
#           alpha = 1
          )

plt.axis('off')
cbar = plt.colorbar(scalarmappaple, shrink=0.5)
cbar.ax.tick_params(labelsize=11)

ax.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=ax.transAxes,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')
#print(italy)

plt.savefig('Mappa_Tot.png', dpi=300)
# Out:
# <ipython-input-132-7edfc6270df9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italy['cumulativa_1000']['TRE'] = italy['cumulativa']['TRE'] / 1072

# %%
cum1     = cum.set_index('area')
vaccini1 = vaccini.set_index('area')

total = cum1.merge(vaccini1 , left_index=True, right_index=True, how='right')

total

sum_ = total.reindex(['PAT', 'PAB', 'EMR', 'VEN',
                      'VDA', 'UMB', 'ABR', 'BAS',
                      'SIC', 'SAR', 'CAL', 'CAM',
                      'PUG', 'PIE', 'LOM', 'MOL',
                      'LAZ', 'LIG', 'TOS', 'FVG', 'MAR']).sum().to_frame().transpose()
sum_ = sum_.rename(index={0: 'ITA'})
sum_['per_1000']        = sum_['totale']     / 60360
sum_['cumulativa_1000'] = sum_['cumulativa'] / 60360
sum_['percentuale_somministrazione'] = sum_['dosi_somministrate'] / sum_['dosi_consegnate'] * 100

ax = total.plot.scatter(x='cumulativa_1000', y='percentuale_somministrazione', 
                        alpha=1, title='Percentuale somministrazioni vs Dosi somministrate per 1000 abitanti',
                        color = 'C0', s=total['cumulativa']/5000)
sum_.plot.scatter( ax=ax, x='cumulativa_1000', y='percentuale_somministrazione', 
                        alpha=1, color = 'orange', s=sum_.loc['ITA', 'cumulativa']/5000)

for i, txt in enumerate(total.index):
    ax.annotate(txt, (total.cumulativa_1000.iat[i], total.percentuale_somministrazione.iat[i]))

txt = 'ITA'
ax.annotate(txt, (sum_.cumulativa_1000.ITA, sum_.percentuale_somministrazione.ITA))
    
ax.set(xlabel='Dosi somministrate per 1000 abitanti', ylabel='Percentuale somministrazioni')


plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')


plt.grid(alpha = 0.2)
plt.savefig('Cartes_CumPerc.png', dpi=300)

plt.show()

# %%
cons
# Out:
#     area        fornitore  numero_dosi data_consegna  colors
# 0    ABR  Pfizer/BioNTech          135    2020-12-27      C0
# 1    ABR  Pfizer/BioNTech         7800    2020-12-30      C0
# 2    ABR  Pfizer/BioNTech         3900    2021-01-05      C0
# 3    ABR  Pfizer/BioNTech         3900    2021-01-07      C0
# 4    ABR  Pfizer/BioNTech         3900    2021-01-11      C0
# ..   ...              ...          ...           ...     ...
# 163  VEN  Pfizer/BioNTech        34125    2021-01-07      C0
# 164  VEN  Pfizer/BioNTech        39000    2021-01-12      C0
# 165  VEN          Moderna         7800    2021-01-13  orange
# 166  VEN  Pfizer/BioNTech         7020    2021-01-20      C0
# 167  VEN  Pfizer/BioNTech        15210    2021-01-21      C0
#
# [168 rows x 5 columns]

# %%
cons_grouped = cons.groupby(cons.fornitore)
cons_pfizer  = cons_grouped.get_group('Pfizer/BioNTech')
cons_moderna = cons_grouped.get_group('Moderna')

cons_moderna.groupby('area').sum().plot(kind = 'pie', x = 'area', y = 'numero_dosi', legend = False, fontsize = 8)
cons_pfizer.groupby('area').sum().plot(kind = 'pie',  x = 'area', y = 'numero_dosi', legend = False, fontsize = 8, wedgeprops=dict(width=0.3, edgecolor='w')) 
cons.groupby('fornitore').sum().plot(kind = 'pie', y = 'numero_dosi',
                                     legend = False,
                                     ylabel = '', xlabel = '', 
                                     fontsize = 8,
                                     title = 'Dosi fornite per azienda', 
                                     colors = {'orange': 'Moderna', 'C0': 'Pfizer/BioNTech'},
                                     autopct='%1.1f%%',
                                     explode=(0, 0.1),
                                     startangle=0, 
#                                     wedgeprops=dict(width=0.8)
                                    )
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')
plt.savefig('Torta_Cons.png', dpi = 300)

# %%
plt.figure()
ax = plt.gca()
ita.plot( y='seconda_1000', kind = 'bar', title = "italia seconde dosi per 1000", xlabel = '')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.rcParams['font.size'] = '8'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.legend(loc="upper left")
plt.xticks(rotation=30)
plt.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='top', rotation='0')

plt.savefig('Italia_Giorn_Seconda.png', dpi=300)

# %%
plt.figure()
ax = plt.gca()
ita.plot( y='prima_1000', kind = 'bar', title = "italia prime dosi per 1000", xlabel = '')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.rcParams['font.size'] = '8'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.legend(loc="upper left")
plt.xticks(rotation=30)
plt.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='top', rotation='0')

plt.savefig('Italia_Cons_Prima.png', dpi=300)

# %%
plt.figure()
ax = plt.gca()
ita.plot( y='cumulativa_seconda_1000', kind = 'bar', title = "italia seconde dosi per 1000", xlabel = '')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.rcParams['font.size'] = '8'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.legend(loc="upper left")
plt.xticks(rotation=30)

plt.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='top', rotation='0')
plt.savefig('Italia_Cum_Seconde.png', dpi=300)

# %%
plt.figure()
ax = plt.gca()
ita.plot( y='cumulativa_prima_1000', kind = 'bar', title = "italia prime dosi per 1000", xlabel = '')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.rcParams['font.size'] = '8'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.legend(loc="upper left")
plt.xticks(rotation=30)

plt.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='top', rotation='0')
plt.savefig('Italia_Cum_Prime.png', dpi=300)

# %%
#%matplotlib widget 
#per plot interattivi
fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})


plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
abr.plot(ax=axes[0,0], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "ABR")
bas.plot(ax=axes[0,1], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "BAS")
cal.plot(ax=axes[0,2], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "CAL")
cam.plot(ax=axes[0,3], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "CAM")
emr.plot(ax=axes[0,4], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "EMR")
fvg.plot(ax=axes[0,5], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "FVG")
laz.plot(ax=axes[0,6], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "LAZ")
lig.plot(ax=axes[1,0], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "LIG")
lom.plot(ax=axes[1,1], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "LOM")
mar.plot(ax=axes[1,2], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "MAR")
mol.plot(ax=axes[1,3], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "MOL")
pab.plot(ax=axes[1,4], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "PAB")
pat.plot(ax=axes[1,5], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "PAT")
pie.plot(ax=axes[1,6], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "PIE")
pug.plot(ax=axes[2,0], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "PUG")
sar.plot(ax=axes[2,1], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "SAR")
sic.plot(ax=axes[2,2], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "SIC")
tos.plot(ax=axes[2,3], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "TOS")
umb.plot(ax=axes[2,4], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "UMB")
vda.plot(ax=axes[2,5], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "VDA")
ven.plot(ax=axes[2,6], y='cumulativa_prima_1000', kind = 'bar', legend = False, xlabel = '', title = "VEN")



axes[0,0].set_title('ABR', y=1.05, pad=0)
axes[0,1].set_title('BAS', y=1.05, pad=0)
axes[0,2].set_title('CAL', y=1.05, pad=0)
axes[0,3].set_title('CAM', y=1.05, pad=0)
axes[0,4].set_title('EMR', y=1.05, pad=0)
axes[0,5].set_title('FVG', y=1.05, pad=0)
axes[0,6].set_title('LAZ', y=1.05, pad=0)
axes[1,0].set_title('LIG', y=1.05, pad=0)
axes[1,1].set_title('LOM', y=1.05, pad=0)
axes[1,2].set_title('MAR', y=1.05, pad=0)
axes[1,3].set_title('MOL', y=1.05, pad=0)
axes[1,4].set_title('PAB', y=1.05, pad=0)
axes[1,5].set_title('PAT', y=1.05, pad=0)
axes[1,6].set_title('PIE', y=1.05, pad=0)
axes[2,0].set_title('PUG', y=1.05, pad=0)
axes[2,1].set_title('SAR', y=1.05, pad=0)
axes[2,2].set_title('SIC', y=1.05, pad=0)
axes[2,3].set_title('TOS', y=1.05, pad=0)
axes[2,4].set_title('UMB', y=1.05, pad=0)
axes[2,5].set_title('VDA', y=1.05, pad=0)
axes[2,6].set_title('VEN', y=1.05, pad=0)

axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'

fig.suptitle("Prime dosi per regione, per 1000 abitanti", fontsize=11)
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Regioni_Cum_Prime.png', dpi=300)
plt.show()

# %%
#%matplotlib widget 
#per plot interattivi
fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})


plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
abr.plot(ax=axes[0,0], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "ABR")
bas.plot(ax=axes[0,1], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "BAS")
cal.plot(ax=axes[0,2], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "CAL")
cam.plot(ax=axes[0,3], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "CAM")
emr.plot(ax=axes[0,4], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "EMR")
fvg.plot(ax=axes[0,5], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "FVG")
laz.plot(ax=axes[0,6], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "LAZ")
lig.plot(ax=axes[1,0], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "LIG")
lom.plot(ax=axes[1,1], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "LOM")
mar.plot(ax=axes[1,2], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "MAR")
mol.plot(ax=axes[1,3], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "MOL")
pab.plot(ax=axes[1,4], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "PAB")
pat.plot(ax=axes[1,5], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "PAT")
pie.plot(ax=axes[1,6], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "PIE")
pug.plot(ax=axes[2,0], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "PUG")
sar.plot(ax=axes[2,1], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "SAR")
sic.plot(ax=axes[2,2], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "SIC")
tos.plot(ax=axes[2,3], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "TOS")
umb.plot(ax=axes[2,4], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "UMB")
vda.plot(ax=axes[2,5], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "VDA")
ven.plot(ax=axes[2,6], y='cumulativa_seconda_1000', kind = 'bar', legend = False, xlabel = '', title = "VEN")



axes[0,0].set_title('ABR', y=1.05, pad=0)
axes[0,1].set_title('BAS', y=1.05, pad=0)
axes[0,2].set_title('CAL', y=1.05, pad=0)
axes[0,3].set_title('CAM', y=1.05, pad=0)
axes[0,4].set_title('EMR', y=1.05, pad=0)
axes[0,5].set_title('FVG', y=1.05, pad=0)
axes[0,6].set_title('LAZ', y=1.05, pad=0)
axes[1,0].set_title('LIG', y=1.05, pad=0)
axes[1,1].set_title('LOM', y=1.05, pad=0)
axes[1,2].set_title('MAR', y=1.05, pad=0)
axes[1,3].set_title('MOL', y=1.05, pad=0)
axes[1,4].set_title('PAB', y=1.05, pad=0)
axes[1,5].set_title('PAT', y=1.05, pad=0)
axes[1,6].set_title('PIE', y=1.05, pad=0)
axes[2,0].set_title('PUG', y=1.05, pad=0)
axes[2,1].set_title('SAR', y=1.05, pad=0)
axes[2,2].set_title('SIC', y=1.05, pad=0)
axes[2,3].set_title('TOS', y=1.05, pad=0)
axes[2,4].set_title('UMB', y=1.05, pad=0)
axes[2,5].set_title('VDA', y=1.05, pad=0)
axes[2,6].set_title('VEN', y=1.05, pad=0)

axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'

fig.suptitle("Seconda dose per regione, per 1000 abitanti", fontsize=11)
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Regioni_Cum_Seconda.png', dpi=300)
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})


abr.plot(ax=axes[0,0], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "ABR"    )
abr.plot(ax=axes[0,0], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
bas.plot(ax=axes[0,1], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "BAS"    )
bas.plot(ax=axes[0,1], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
cal.plot(ax=axes[0,2], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "CAL"    )
cal.plot(ax=axes[0,2], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
cam.plot(ax=axes[0,3], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "CAM"    )
cam.plot(ax=axes[0,3], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
emr.plot(ax=axes[0,4], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "EMR"    )
emr.plot(ax=axes[0,4], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
fvg.plot(ax=axes[0,5], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "FVG"    )
fvg.plot(ax=axes[0,5], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
laz.plot(ax=axes[0,6], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "LAZ"    )
laz.plot(ax=axes[0,6], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
lig.plot(ax=axes[1,0], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "LIG"    )
lig.plot(ax=axes[1,0], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
lom.plot(ax=axes[1,1], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "LOM"    )
lom.plot(ax=axes[1,1], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
mar.plot(ax=axes[1,2], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "MAR"    )
mar.plot(ax=axes[1,2], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
mol.plot(ax=axes[1,3], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "MOL"    )
mol.plot(ax=axes[1,3], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pab.plot(ax=axes[1,4], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "PAB"    )
pab.plot(ax=axes[1,4], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pat.plot(ax=axes[1,5], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "PAT"    )
pat.plot(ax=axes[1,5], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pie.plot(ax=axes[1,6], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "PIE"    )
pie.plot(ax=axes[1,6], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pug.plot(ax=axes[2,0], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "PUG"    )
pug.plot(ax=axes[2,0], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
sar.plot(ax=axes[2,1], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "SAR"    )
sar.plot(ax=axes[2,1], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
sic.plot(ax=axes[2,2], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "SIC"    )
sic.plot(ax=axes[2,2], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
tos.plot(ax=axes[2,3], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "TOS"    )
tos.plot(ax=axes[2,3], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
umb.plot(ax=axes[2,4], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "UMB"    )
umb.plot(ax=axes[2,4], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
vda.plot(ax=axes[2,5], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "VDA"    )
vda.plot(ax=axes[2,5], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
ven.plot(ax=axes[2,6], y='prima_1000', kind = 'bar',  legend = False, xlabel = '', title = "VEN"    )
ven.plot(ax=axes[2,6], y='avg_prima_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )



axes[0,0].set_title('ABR', y=1.05, pad=0)
axes[0,1].set_title('BAS', y=1.05, pad=0)
axes[0,2].set_title('CAL', y=1.05, pad=0)
axes[0,3].set_title('CAM', y=1.05, pad=0)
axes[0,4].set_title('EMR', y=1.05, pad=0)
axes[0,5].set_title('FVG', y=1.05, pad=0)
axes[0,6].set_title('LAZ', y=1.05, pad=0)
axes[1,0].set_title('LIG', y=1.05, pad=0)
axes[1,1].set_title('LOM', y=1.05, pad=0)
axes[1,2].set_title('MAR', y=1.05, pad=0)
axes[1,3].set_title('MOL', y=1.05, pad=0)
axes[1,4].set_title('PAB', y=1.05, pad=0)
axes[1,5].set_title('PAT', y=1.05, pad=0)
axes[1,6].set_title('PIE', y=1.05, pad=0)
axes[2,0].set_title('PUG', y=1.05, pad=0)
axes[2,1].set_title('SAR', y=1.05, pad=0)
axes[2,2].set_title('SIC', y=1.05, pad=0)
axes[2,3].set_title('TOS', y=1.05, pad=0)
axes[2,4].set_title('UMB', y=1.05, pad=0)
axes[2,5].set_title('VDA', y=1.05, pad=0)
axes[2,6].set_title('VEN', y=1.05, pad=0)

axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.setp(axes[2,0].get_xticklabels(), rotation=90)
plt.setp(axes[2,1].get_xticklabels(), rotation=90)
plt.setp(axes[2,2].get_xticklabels(), rotation=90)
plt.setp(axes[2,3].get_xticklabels(), rotation=90)
plt.setp(axes[2,4].get_xticklabels(), rotation=90)
plt.setp(axes[2,5].get_xticklabels(), rotation=90)
plt.setp(axes[2,6].get_xticklabels(), rotation=90)


fig.suptitle("Prime dosi per regione, per 1000 abitanti", fontsize=11)
plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Regioni_Giorn_Prima.png', dpi=300)
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=7, sharey=True, sharex=True, dpi = 200, gridspec_kw={'hspace': 0.25, 'wspace': 0.})


abr.plot(ax=axes[0,0], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "ABR"    )
abr.plot(ax=axes[0,0], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
bas.plot(ax=axes[0,1], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "BAS"    )
bas.plot(ax=axes[0,1], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
cal.plot(ax=axes[0,2], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "CAL"    )
cal.plot(ax=axes[0,2], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
cam.plot(ax=axes[0,3], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "CAM"    )
cam.plot(ax=axes[0,3], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
emr.plot(ax=axes[0,4], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "EMR"    )
emr.plot(ax=axes[0,4], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
fvg.plot(ax=axes[0,5], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "FVG"    )
fvg.plot(ax=axes[0,5], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
laz.plot(ax=axes[0,6], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "LAZ"    )
laz.plot(ax=axes[0,6], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
lig.plot(ax=axes[1,0], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "LIG"    )
lig.plot(ax=axes[1,0], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
lom.plot(ax=axes[1,1], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "LOM"    )
lom.plot(ax=axes[1,1], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
mar.plot(ax=axes[1,2], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "MAR"    )
mar.plot(ax=axes[1,2], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
mol.plot(ax=axes[1,3], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "MOL"    )
mol.plot(ax=axes[1,3], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pab.plot(ax=axes[1,4], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "PAB"    )
pab.plot(ax=axes[1,4], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pat.plot(ax=axes[1,5], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "PAT"    )
pat.plot(ax=axes[1,5], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pie.plot(ax=axes[1,6], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "PIE"    )
pie.plot(ax=axes[1,6], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
pug.plot(ax=axes[2,0], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "PUG"    )
pug.plot(ax=axes[2,0], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
sar.plot(ax=axes[2,1], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "SAR"    )
sar.plot(ax=axes[2,1], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
sic.plot(ax=axes[2,2], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "SIC"    )
sic.plot(ax=axes[2,2], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
tos.plot(ax=axes[2,3], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "TOS"    )
tos.plot(ax=axes[2,3], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
umb.plot(ax=axes[2,4], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "UMB"    )
umb.plot(ax=axes[2,4], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
vda.plot(ax=axes[2,5], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "VDA"    )
vda.plot(ax=axes[2,5], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )
ven.plot(ax=axes[2,6], y='seconda_1000', kind = 'bar',  legend = False, xlabel = '', title = "VEN"    )
ven.plot(ax=axes[2,6], y='avg_seconda_1000', kind = 'line', legend = False, xlabel = '', color = 'orange' )



axes[0,0].set_title('ABR', y=1.05, pad=0)
axes[0,1].set_title('BAS', y=1.05, pad=0)
axes[0,2].set_title('CAL', y=1.05, pad=0)
axes[0,3].set_title('CAM', y=1.05, pad=0)
axes[0,4].set_title('EMR', y=1.05, pad=0)
axes[0,5].set_title('FVG', y=1.05, pad=0)
axes[0,6].set_title('LAZ', y=1.05, pad=0)
axes[1,0].set_title('LIG', y=1.05, pad=0)
axes[1,1].set_title('LOM', y=1.05, pad=0)
axes[1,2].set_title('MAR', y=1.05, pad=0)
axes[1,3].set_title('MOL', y=1.05, pad=0)
axes[1,4].set_title('PAB', y=1.05, pad=0)
axes[1,5].set_title('PAT', y=1.05, pad=0)
axes[1,6].set_title('PIE', y=1.05, pad=0)
axes[2,0].set_title('PUG', y=1.05, pad=0)
axes[2,1].set_title('SAR', y=1.05, pad=0)
axes[2,2].set_title('SIC', y=1.05, pad=0)
axes[2,3].set_title('TOS', y=1.05, pad=0)
axes[2,4].set_title('UMB', y=1.05, pad=0)
axes[2,5].set_title('VDA', y=1.05, pad=0)
axes[2,6].set_title('VEN', y=1.05, pad=0)

axes[2,0].xaxis.set_major_locator(mdates.DayLocator(interval=3))

plt.setp(axes[2,0].get_xticklabels(), rotation=90)
plt.setp(axes[2,1].get_xticklabels(), rotation=90)
plt.setp(axes[2,2].get_xticklabels(), rotation=90)
plt.setp(axes[2,3].get_xticklabels(), rotation=90)
plt.setp(axes[2,4].get_xticklabels(), rotation=90)
plt.setp(axes[2,5].get_xticklabels(), rotation=90)
plt.setp(axes[2,6].get_xticklabels(), rotation=90)


fig.suptitle("Seconda dose per regione, per 1000 abitanti", fontsize=11)
plt.rcParams['font.size'] = '4'
plt.rcParams['xtick.labelsize'] = '4'
plt.rcParams['ytick.labelsize'] = '4'
plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Regioni_Giorn_Seconda.png', dpi=300)
plt.show()

# %%
italy = gpd.read_file('italy-with-regions//reg2011_g.shp')

cum1 = cum.set_index('area')
sum_ = cum1.reindex(['PAT', 'PAB']).sum().to_frame().transpose()
sum_ = sum_.rename(index={0: 'TRE'})

cum1.drop(['PAT', 'PAB'],inplace=True)
cum1 = cum1.append(sum_)
cum1 = cum1.sort_index()

italy.sort_values(by = 'NOME_REG', inplace = True)
italy.reset_index(drop=True,       inplace = True)
italy.index = cum1.index

italy = italy.merge(cum1,left_index=True, right_index=True, how='right')


italy['cumulativa_seconda_1000']['TRE'] = italy['cumulativa_seconda']['TRE'] / 1072

fig, ax = plt.subplots(1, figsize=(15, 15))

col = 'cumulativa_seconda_1000'

ax.set_title('Seconde dosi somministrate per regione per 1000 abitanti', 
             fontdict={'fontsize':'25', 'fontweight':'3'}, 
             color='Orange', 
             fontfamily='monospace')


normalize = mcolors.Normalize(vmin=italy['cumulativa_seconda_1000'].min(), vmax=italy['cumulativa_seconda_1000'].max())
#colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap="Blues")
scalarmappaple.set_array(italy['cumulativa_seconda_1000'])

italy.plot(ax=ax,
           column=col,
           cmap="Blues",
#           cmap=colormap,
#           label='ciao',
#           legend=True,
#           categorical=False
#           alpha = 1
          )

plt.axis('off')
cbar = plt.colorbar(scalarmappaple, shrink=0.5)
cbar.ax.tick_params(labelsize=11)

ax.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=ax.transAxes,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')
#print(italy)

plt.savefig('Mappa_Seconda.png', dpi=300)
# Out:
# <ipython-input-144-b8c4001f5fe7>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italy['cumulativa_seconda_1000']['TRE'] = italy['cumulativa_seconda']['TRE'] / 1072

# %%
italy = gpd.read_file('italy-with-regions//reg2011_g.shp')

cum1 = cum.set_index('area')
sum_ = cum1.reindex(['PAT', 'PAB']).sum().to_frame().transpose()
sum_ = sum_.rename(index={0: 'TRE'})

cum1.drop(['PAT', 'PAB'],inplace=True)
cum1 = cum1.append(sum_)
cum1 = cum1.sort_index()

italy.sort_values(by = 'NOME_REG', inplace = True)
italy.reset_index(drop=True,       inplace = True)
italy.index = cum1.index

italy = italy.merge(cum1,left_index=True, right_index=True, how='right')


italy['cumulativa_prima_1000']['TRE'] = italy['cumulativa_prima']['TRE'] / 1072

fig, ax = plt.subplots(1, figsize=(15, 15))

col = 'cumulativa_prima_1000'

ax.set_title('Prime dosi somministrate per regione per 1000 abitanti', 
             fontdict={'fontsize':'25', 'fontweight':'3'}, 
             color='Orange', 
             fontfamily='monospace')


normalize = mcolors.Normalize(vmin=italy['cumulativa_prima_1000'].min(), vmax=italy['cumulativa_prima_1000'].max())
#colormap = cm.jet

scalarmappaple = cm.ScalarMappable(norm=normalize, cmap="Blues")
scalarmappaple.set_array(italy['cumulativa_prima_1000'])

italy.plot(ax=ax,
           column=col,
           cmap="Blues",
#           cmap=colormap,
#           label='ciao',
#           legend=True,
#           categorical=False
#           alpha = 1
          )

plt.axis('off')
cbar = plt.colorbar(scalarmappaple, shrink=0.5)
cbar.ax.tick_params(labelsize=11)

ax.text(1, 0, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=ax.transAxes,
        fontsize=8, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')
#print(italy)

plt.savefig('Mappa_Prima.png', dpi=300)
# Out:
# <ipython-input-145-418698ea1f7c>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   italy['cumulativa_prima_1000']['TRE'] = italy['cumulativa_prima']['TRE'] / 1072

# %%
total = cum.set_index('area')

sum_ = total.reindex(['PAT', 'PAB', 'EMR', 'VEN',
                      'VDA', 'UMB', 'ABR', 'BAS',
                      'SIC', 'SAR', 'CAL', 'CAM',
                      'PUG', 'PIE', 'LOM', 'MOL',
                      'LAZ', 'LIG', 'TOS', 'FVG', 'MAR']).sum().to_frame().transpose()
sum_ = sum_.rename(index={0: 'ITA'})
sum_['per_1000']        = sum_['totale']     / 60360
sum_['cumulativa_1000'] = sum_['cumulativa'] / 60360
sum_['cumulativa_prima_1000'] = sum_['cumulativa_prima'] / 60360
sum_['cumulativa_seconda_1000'] = sum_['cumulativa_seconda'] / 60360

ax = total.plot.scatter(x='cumulativa_prima_1000', y='cumulativa_seconda_1000', 
                        alpha=1, title='Prime dosi vs Seconde dosi',
                        color = 'C0', s=total['cumulativa']/5000)
sum_.plot.scatter( ax=ax, x='cumulativa_prima_1000', y='cumulativa_seconda_1000',
                        alpha=1, color = 'orange', s=sum_.loc['ITA', 'cumulativa']/5000)

for i, txt in enumerate(total.index):
    ax.annotate(txt, (total.cumulativa_prima_1000.iat[i], total.cumulativa_seconda_1000.iat[i]))

txt = 'ITA'
ax.annotate(txt, (sum_.cumulativa_prima_1000.ITA, sum_.cumulativa_seconda_1000.ITA))
    
ax.set(xlabel='Prime dosi somministrate per 1000 abitanti', ylabel='Seconde dosi somministrate per 1000 abitanti')


plt.text(0.9, 0., 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')


plt.grid(alpha = 0.2)
plt.savefig('Cartes_PrimeSeconde.png', dpi=300)

plt.show()

# %%
# %matplotlib widget
somm1_laz[somm1_emr.columns[6:10]].sum().plot.bar(rot=0)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
somm1_pab.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_emr.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_abr.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_bas.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_cal.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_cam.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_fvg.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_laz.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_lig.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_lom.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_mar.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_mol.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_pat.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_pug.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_pie.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_sar.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_sic.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_tos.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_umb.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_vda.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)
somm1_ven.rename(columns={'categoria_operatori_sanitari_sociosanitari': 'OP_SAN', 
                          'categoria_personale_non_sanitario': 'OP_NSAN',
                          'categoria_ospiti_rsa': 'RSA',
                          'categoria_over80': '80+'}, inplace = True)

somm1_laz
# Out:
# /home/aidin/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      data_somministrazione        fornitore area fascia_anagrafica  \
# 41              2020-12-27  Pfizer/BioNTech  LAZ             20-29
# 42              2020-12-27  Pfizer/BioNTech  LAZ             30-39
# 43              2020-12-27  Pfizer/BioNTech  LAZ             40-49
# 44              2020-12-27  Pfizer/BioNTech  LAZ             50-59
# 45              2020-12-27  Pfizer/BioNTech  LAZ             60-69
# ...                    ...              ...  ...               ...
# 4381            2021-01-23  Pfizer/BioNTech  LAZ             50-59
# 4382            2021-01-23  Pfizer/BioNTech  LAZ             60-69
# ...

# %%
# %matplotlib inline
fig, axes = plt.subplots(nrows=3, ncols=7, dpi = 1000, gridspec_kw={'hspace': -0.5, 'wspace': 0.05})



somm1_emr[somm1_emr.columns[6:9]].sum().plot.pie(ax=axes[0,4], rot=0,  legend=False, xlabel = '', title = "EMR", ylabel = '', textprops={'fontsize': 2})
somm1_abr[somm1_abr.columns[6:9]].sum().plot.pie(ax=axes[0,0], rot=0,  legend=False, xlabel = '', title = "ABR", ylabel = '', textprops={'fontsize': 2})
somm1_bas[somm1_bas.columns[6:9]].sum().plot.pie(ax=axes[0,1], rot=0,  legend=False, xlabel = '', title = "BAS", ylabel = '', textprops={'fontsize': 2})
somm1_cal[somm1_cal.columns[6:9]].sum().plot.pie(ax=axes[0,2], rot=0,  legend=False, xlabel = '', title = "CAL", ylabel = '', textprops={'fontsize': 2})
somm1_cam[somm1_cam.columns[6:9]].sum().plot.pie(ax=axes[0,3], rot=0,  legend=False, xlabel = '', title = "CAM", ylabel = '', textprops={'fontsize': 2})
somm1_fvg[somm1_fvg.columns[6:9]].sum().plot.pie(ax=axes[0,5], rot=0,  legend=False, xlabel = '', title = "FVG", ylabel = '', textprops={'fontsize': 2})
somm1_laz[somm1_laz.columns[6:9]].sum().plot.pie(ax=axes[0,6], rot=0,  legend=False, xlabel = '', title = "LAZ", ylabel = '', textprops={'fontsize': 2})
somm1_lig[somm1_lig.columns[6:9]].sum().plot.pie(ax=axes[1,0], rot=0,  legend=False, xlabel = '', title = "LIG", ylabel = '', textprops={'fontsize': 2})
somm1_lom[somm1_lom.columns[6:9]].sum().plot.pie(ax=axes[1,1], rot=0,  legend=False, xlabel = '', title = "LOM", ylabel = '', textprops={'fontsize': 2})
somm1_mar[somm1_mar.columns[6:9]].sum().plot.pie(ax=axes[1,2], rot=0,  legend=False, xlabel = '', title = "MAR", ylabel = '', textprops={'fontsize': 2})
somm1_mol[somm1_mol.columns[6:9]].sum().plot.pie(ax=axes[1,3], rot=0,  legend=False, xlabel = '', title = "MOL", ylabel = '', textprops={'fontsize': 2})
somm1_pab[somm1_pab.columns[6:9]].sum().plot.pie(ax=axes[1,4], rot=0,  legend=False, xlabel = '', title = "PAB", ylabel = '', textprops={'fontsize': 2})
somm1_pat[somm1_pat.columns[6:9]].sum().plot.pie(ax=axes[1,5], rot=0,  legend=False, xlabel = '', title = "PAT", ylabel = '', textprops={'fontsize': 2})
somm1_pie[somm1_pie.columns[6:9]].sum().plot.pie(ax=axes[1,6], rot=0,  legend=False, xlabel = '', title = "PIE", ylabel = '', textprops={'fontsize': 2})
somm1_pug[somm1_pug.columns[6:9]].sum().plot.pie(ax=axes[2,0], rot=0,  legend=False, xlabel = '', title = "PUG", ylabel = '', textprops={'fontsize': 2})
somm1_sar[somm1_sar.columns[6:9]].sum().plot.pie(ax=axes[2,1], rot=0,  legend=False, xlabel = '', title = "SAR", ylabel = '', textprops={'fontsize': 2})
somm1_sic[somm1_sic.columns[6:9]].sum().plot.pie(ax=axes[2,2], rot=0,  legend=False, xlabel = '', title = "SIC", ylabel = '', textprops={'fontsize': 2})
somm1_tos[somm1_tos.columns[6:9]].sum().plot.pie(ax=axes[2,3], rot=0,  legend=False, xlabel = '', title = "TOS", ylabel = '', textprops={'fontsize': 2})
somm1_umb[somm1_umb.columns[6:9]].sum().plot.pie(ax=axes[2,4], rot=0,  legend=False, xlabel = '', title = "UMB", ylabel = '', textprops={'fontsize': 2})
somm1_vda[somm1_vda.columns[6:9]].sum().plot.pie(ax=axes[2,5], rot=0,  legend=False, xlabel = '', title = "VDA", ylabel = '', textprops={'fontsize': 2})
somm1_ven[somm1_ven.columns[6:9]].sum().plot.pie(ax=axes[2,6], rot=0,  legend=False, xlabel = '', title = "VEN", ylabel = '', textprops={'fontsize': 2})

plt.rcParams['font.size'] = '4' 
axes[0,0].title.set_size(4)
axes[0,1].title.set_size(4)
axes[0,2].title.set_size(4)
axes[0,3].title.set_size(4)
axes[0,4].title.set_size(4)
axes[0,5].title.set_size(4)
axes[0,6].title.set_size(4)
axes[1,0].title.set_size(4)
axes[1,1].title.set_size(4)
axes[1,2].title.set_size(4)
axes[1,3].title.set_size(4)
axes[1,4].title.set_size(4)
axes[1,5].title.set_size(4)
axes[1,6].title.set_size(4)
axes[2,0].title.set_size(4)
axes[2,1].title.set_size(4)
axes[2,2].title.set_size(4)
axes[2,3].title.set_size(4)
axes[2,4].title.set_size(4)
axes[2,5].title.set_size(4)
axes[2,6].title.set_size(4)

axes[0,0].set_title('ABR', y=1.0, pad=0)
axes[0,1].set_title('BAS', y=1.0, pad=0)
axes[0,2].set_title('CAL', y=1.0, pad=0)
axes[0,3].set_title('CAM', y=1.0, pad=0)
axes[0,4].set_title('EMR', y=1.0, pad=0)
axes[0,5].set_title('FVG', y=1.0, pad=0)
axes[0,6].set_title('LAZ', y=1.0, pad=0)
axes[1,0].set_title('LIG', y=1.0, pad=0)
axes[1,1].set_title('LOM', y=1.0, pad=0)
axes[1,2].set_title('MAR', y=1.0, pad=0)
axes[1,3].set_title('MOL', y=1.0, pad=0)
axes[1,4].set_title('PAB', y=1.0, pad=0)
axes[1,5].set_title('PAT', y=1.0, pad=0)
axes[1,6].set_title('PIE', y=1.0, pad=0)
axes[2,0].set_title('PUG', y=1.0, pad=0)
axes[2,1].set_title('SAR', y=1.0, pad=0)
axes[2,2].set_title('SIC', y=1.0, pad=0)
axes[2,3].set_title('TOS', y=1.0, pad=0)
axes[2,4].set_title('UMB', y=1.0, pad=0)
axes[2,5].set_title('VDA', y=1.0, pad=0)
axes[2,6].set_title('VEN', y=1.0, pad=0)

fig.suptitle("Divisione per categoria per regione", fontsize=10, y= 0.85)
plt.text(0.9, 0.2, 'Grafico di Aidin Attar - Fonte dati: https://github.com/italia/covid19-opendata-vaccini', transform=plt.gcf().transFigure,
        fontsize=4, color='black', alpha=0.8,
        ha='right', va='bottom', rotation='0')

plt.savefig('Torte_Regioni_Categorie.png', dpi=1000)
